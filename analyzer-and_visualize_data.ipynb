# %%
from googleapiclient.discovery import build # Google'dan çekeceğimiz bilgiler için bir temel oluşturan methodttur.
import pandas as pd
import seaborn as sns

# %%
api_key = 'AIzaSyAdhrZ090WKAv_E_c9-5NHXdQ9MJ3tzqNU'

channel_id = 'UCv6jcPwFujuTIwFQ11jt1Yw'# id = 'UCkRY4J8G_K8SEWZRLbke-Q'

channel_ids = ['UCnz-ZXXER4jOvuED5trXfEA', # id = UCnz-ZXXER4jOvuED5trXfEA,UCvzrbCJbp7jw2EdPPblJy8w,UCUT1S-W5BIBUu_vzwhyGNVg,UCfWlZ2vavQ_Q8pPkf4-sPIw,UCUNrtwdLtsOerh9nCSIxjdg
               'UCvzrbCJbp7jw2EdPPblJy8w',
               'UCUT1S-W5BIBUu_vzwhyGNVg',
               'UCfWlZ2vavQ_Q8pPkf4-sPIw',
               'UCUNrtwdLtsOerh9nCSIxjdg']

# %%
def get_channel_statics(youtube, channel_id):
    request = youtube.channels().list(
        part = 'snippet,contentDetails,statistics', # Benim istediğim veri bölümleri
        id = channel_id
    )
    response = request.execute() # Aldığımız yanıtları işliyorum ve response değişkenine atıyorum
    return response

# %%
youtube = build('youtube', 'v3', developerKey=api_key) # Youtube ile bağlantı oluşturduk
get_channel_statics(youtube=youtube, channel_id=channel_id)
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'UWtbULGzY-ghiMnDv2QO7GniDh0',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'ZqGaTGYm9_CAkXRXQsk40WyxmfQ',
#    'id': 'UCv6jcPwFujuTIwFQ11jt1Yw',
#    'snippet': {'title': 'Barış Özcan',
#     'description': 'I tell stories about art, design and technology.\nSanat, tasarım ve teknoloji konularına "hikaye anlatıcılığı" (storytelling) perspektifinden bakış.',
#     'customUrl': 'barisozcan',
#     'publishedAt': '2007-01-07T10:21:25Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AIdro_mdvFBaWJ3sPLwGj3W5wjSzhllxR8Gg4qXhXdAR-m4piAK6=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/AIdro_mdvFBaWJ3sPLwGj3W5wjSzhllxR8Gg4qXhXdAR-m4piAK6=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/ytc/AIdro_mdvFBaWJ3sPLwGj3W5wjSzhllxR8Gg4qXhXdAR-m4piAK6=s800-c-k-c0x00ffffff-no-rj',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': 'Barış Özcan',
#      'description': 'I tell stories about art, design and technology.\nSanat, tasarım ve teknoloji konularına "hikaye anlatıcılığı" (storytelling) perspektifinden bakış.'},
#     'country': 'US'},
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUv6jcPwFujuTIwFQ11jt1Yw'}},
#    'statistics': {'viewCount': '913946550',
#     'subscriberCount': '6640000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '849'}}]}

# %%
def get_channel_statics(youtube, channel_id):
    request = youtube.channels().list(
        part = 'snippet,contentDetails,statistics', # Benim istediğim veri bölümleri
        id = channel_id
    )
    response:dict = request.execute() # Aldığımız yanıtları işliyorum ve response değişkenine atıyorum
    
    data = dict(
        Channel_name = response['items'][0]['snippet']['title'], # Kanal ismini aldık
        # Kanalın Abone sayısını alınız
        Subscribers = response['items'][0]['statistics']['subscriberCount'],
        # Toplam Görüntülenme Sayısını
        Views  = response['items'][0]['statistics']['viewCount'],
        #Toplam Video Sayısını
        total_videos = response['items'][0]['statistics']['videoCount']
    )
    return data

# %%
get_channel_statics(youtube=youtube, channel_id=channel_id)
# Out:
# {'Channel_name': 'Barış Özcan',
#  'Subscribers': '6640000',
#  'Views': '913946550',
#  'total_videos': '849'}

# %%
def get_channel_statics(youtube, channel_id):
    request = youtube.channels().list(
        part = 'snippet,contentDetails,statistics', # Benim istediğim veri bölümleri
        id = channel_id
    )
    response:dict = request.execute() # Aldığımız yanıtları işliyorum ve response değişkenine atıyorum
    all_data = []
    for item in range(len(response['items'])):
        data = dict(
            Channel_name = response['items'][item]['snippet']['title'], # Kanal ismini aldık
            # Kanalın Abone sayısını alınız
            Subscribers = response['items'][item]['statistics']['subscriberCount'],
            # Toplam Görüntülenme Sayısını
            Views  = response['items'][item]['statistics']['viewCount'],
            #Toplam Video Sayısını
            total_videos = response['items'][item]['statistics']['videoCount'],
            playlist_id = response['items'][item]['contentDetails']['relatedPlaylists']['uploads']
        )
        all_data.append(data)
    return all_data

# %%
channel_statistics = get_channel_statics(youtube=youtube, channel_id=channel_ids)
channel_statistics
# Out:
# [{'Channel_name': 'techTFQ',
#   'Subscribers': '348000',
#   'Views': '19711019',
#   'total_videos': '139',
#   'playlist_id': 'UUnz-ZXXER4jOvuED5trXfEA'},
#  {'Channel_name': 'Barberstown Tv',
#   'Subscribers': '1600000',
#   'Views': '1182209751',
#   'total_videos': '523',
#   'playlist_id': 'UUUT1S-W5BIBUu_vzwhyGNVg'},
#  {'Channel_name': 'Angelo Shoe Shine',
#   'Subscribers': '415000',
#   'Views': '113536782',
#   'total_videos': '291',
#   'playlist_id': 'UUvzrbCJbp7jw2EdPPblJy8w'},
#  {'Channel_name': 'KANAL İSTANBUL            (Sokak Sanatçıları)',
#   'Subscribers': '66700',
#   'Views': '44370906',
#   'total_videos': '929',
#   'playlist_id': 'UUfWlZ2vavQ_Q8pPkf4-sPIw'},
#  {'Channel_name': 'Kudsi Erguner Ensemble - Topic',
#   'Subscribers': '17300',
#   'Views': '17994810',
#   'total_videos': '241',
#   'playlist_id': 'UUUNrtwdLtsOerh9nCSIxjdg'}]

# %%
channel_data = pd.DataFrame(channel_statistics)
channel_data
# Out:
#                                     Channel_name Subscribers       Views  \
# 0                                        techTFQ      348000    19711019
# 1                                 Barberstown Tv     1600000  1182209751
# 2                              Angelo Shoe Shine      415000   113536782
# 3  KANAL İSTANBUL            (Sokak Sanatçıları)       66700    44370906
# 4                 Kudsi Erguner Ensemble - Topic       17300    17994810
#
#   total_videos               playlist_id
# 0          139  UUnz-ZXXER4jOvuED5trXfEA
# 1          523  UUUT1S-W5BIBUu_vzwhyGNVg
# 2          291  UUvzrbCJbp7jw2EdPPblJy8w
# 3          929  UUfWlZ2vavQ_Q8pPkf4-sPIw
# 4          241  UUUNrtwdLtsOerh9nCSIxjdg

# %%
channel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Channel_name  5 non-null      object
#  1   Subscribers   5 non-null      object
#  2   Views         5 non-null      object
#  3   total_videos  5 non-null      object
#  4   playlist_id   5 non-null      object
# dtypes: object(5)
# memory usage: 332.0+ bytes

# %%
channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['total_videos'] = pd.to_numeric(channel_data['total_videos'])
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# total_videos     int64
# playlist_id     object
# dtype: object

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (14,5))

ax = sns.barplot(data  = channel_data, x = 'Channel_name', y = 'Subscribers')
plt.title('Kanalların Abone Sayıları')
plt.xticks(rotation = 90) # X  ekseninde ki isimleri 90 derece döndürdük
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (14,5))

ax = sns.barplot(data  = channel_data, x = 'Channel_name', y = 'total_videos')
plt.title('Kanalların Toplam Video Sayıları')
plt.xticks(rotation = 90) # X  ekseninde ki isimleri 90 derece döndürdük
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (14,5))

ax = sns.barplot(data  = channel_data, x = 'Channel_name', y = 'Views')
plt.title('Kanalların İzlenme Sayıları')
plt.xticks(rotation = 90) # X  ekseninde ki isimleri 90 derece döndürdük
plt.show()

# %%
filtered_data = channel_data[channel_data['Channel_name'] == 'Kudsi Erguner Ensemble - Topic']
filtered_data
# Out:
#                      Channel_name  Subscribers     Views  total_videos  \
# 4  Kudsi Erguner Ensemble - Topic        17300  17994810           241
#
#                 playlist_id
# 4  UUUNrtwdLtsOerh9nCSIxjdg

# %%
playlist_id  = filtered_data['playlist_id'][4]
playlist_id
# Out:
# 'UUUNrtwdLtsOerh9nCSIxjdg'

# %%
def get_video_real_id(youtube, playlist_id):
    request  = youtube.playlistItems().list(
        part = 'contentDetails',
        playlistId = playlist_id,
        maxResults = 50
    )
    response = request.execute()
    video_ids = []
    for item in range(0,len(response['items'])):
        video_ids.append(response['items'][item]['contentDetails']['videoId']) # Video İd bilgisini  aLMAK İÇİN 50 defalık bir döngü YAPTIk
    next_page_token = response.get('nextPageToken')

    more_pages = True
    while more_pages: # more_pages değişkeni True değeri olduğu sürece döngü devam etsin
        if next_page_token is None:
            more_pages = False
        else: # Eğer Benim Daha Fazla Sayfaya İhtiyacım Varsa
            request  = youtube.playlistItems().list(
                        part = 'contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token
)           
            response = request.execute()
            for item in range(0,len(response['items'])):
                video_ids.append(response['items'][item]['contentDetails']['videoId'])
            next_page_token = response.get('nextPageToken')

    return video_ids

# %%
video_ids = get_video_real_id(youtube, playlist_id='UUUT1S-W5BIBUu_vzwhyGNVg')
len(video_ids)
# Out:
# 522

# %%
def get_video_details(youtube, video_ids):
    request = youtube.videos().list(
        part = 'snippet, statistics',
        id = ','.join(video_ids[:50])
    )
    response = request.execute()
    return response

# %%
get_video_details(youtube, video_ids)
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': '8fovcYhoxlDvEVHEBveyI-TUzNM',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'TeVqPfWb0VkhSVzeGhxAKKsPh4Q',
#    'id': 'pkyQtP_36qU',
#    'snippet': {'publishedAt': '2025-01-01T14:58:18Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen aralara doğal dokunuş 😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pkyQtP_36qU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/pkyQtP_36qU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/pkyQtP_36qU/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/pkyQtP_36qU/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/pkyQtP_36qU/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen aralara doğal dokunuş 😳💈',
#      'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '7838',
#     'likeCount': '156',
#     'favoriteCount': '0',
#     'commentCount': '0'}},
#   {'kind': 'youtube#video',
#    'etag': 'JCqvP_O_Sy6qgMi6BBj8zpHH0Rw',
#    'id': 'oPFNGtptlVE',
#    'snippet': {'publishedAt': '2024-12-30T16:36:14Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen ders niteliğinde 😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/oPFNGtptlVE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/oPFNGtptlVE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/oPFNGtptlVE/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/oPFNGtptlVE/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/oPFNGtptlVE/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen ders niteliğinde 😳💈', 'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '3847',
#     'likeCount': '153',
#     'favoriteCount': '0',
#     'commentCount': '2'}},
#   {'kind': 'youtube#video',
#    'etag': '2Hqu4OaTgSU_LFBZnt_oeLXkMow',
#    'id': 'HmdyXIwsRZA',
#    'snippet': {'publishedAt': '2024-12-27T14:38:07Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen aralara 😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HmdyXIwsRZA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/HmdyXIwsRZA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/HmdyXIwsRZA/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/HmdyXIwsRZA/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/HmdyXIwsRZA/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen aralara 😳💈', 'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '7158',
#     'likeCount': '148',
#     'favoriteCount': '0',
#     'commentCount': '3'}},
#   {'kind': 'youtube#video',
#    'etag': '254k6m1s3-ndecCDMMDEgz1956E',
#    'id': 'kUy9ZswO9Is',
#    'snippet': {'publishedAt': '2024-12-26T08:51:44Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'SICACIK SOHBET EŞLİĞİNDE EVSİZ ADAMA YEPYENİ BİR GÖRÜNÜM!!?',
#     'description': 'Hayat her zaman kolay değil, ama bazen küçük bir dokunuş büyük bir değişimlere yol açabilir. Bu videoda, hayatın zorluklarını aşmaya çalışan değerli bir abimizle tanıştık. Ona sadece bir saç ve sakal tıraşı değil, aynı zamanda samimi bir sohbet ve bir nebze de olsa moral vermeye çalıştık. Herkesin bir hikayesi var, ve bu hikayeler bazen bir tıraş koltuğunda ortaya çıkar. Bu özel anları sizinle paylaşmaktan mutluluk duyuyoruz.\n\n"Her küçük iyilik umut ışığıdır.\nizleyin,paylaşın,ilham olun"\n\nİYİ SEYİRLER..\n\ninstagram: https://www.instagram.com/barberstown\n\nhttps://www.instagram.com/barberstownisiklar\n\nhttps://www.instagram.com/barberstownetiler\n\nTiktok: https://www.tiktok.com/@barberstown\n\n\n\n#barber #shave #dégradé #fade #highfade #oldscissors #barberstown  #berber #traş #sakal #asmr',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kUy9ZswO9Is/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/kUy9ZswO9Is/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/kUy9ZswO9Is/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/kUy9ZswO9Is/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/kUy9ZswO9Is/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'tags': ['barber',
#      'shave',
#      'fade',
#      'oldscissors',
#      'barberstown',
#      'berber',
#      'tıraş',
#      'traş',
#      'sakal',
#      'asma',
#      'berd',
#      'howto'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'SICACIK SOHBET EŞLİĞİNDE EVSİZ ADAMA YEPYENİ BİR GÖRÜNÜM!!?',
#      'description': 'Hayat her zaman kolay değil, ama bazen küçük bir dokunuş büyük bir değişimlere yol açabilir. Bu videoda, hayatın zorluklarını aşmaya çalışan değerli bir abimizle tanıştık. Ona sadece bir saç ve sakal tıraşı değil, aynı zamanda samimi bir sohbet ve bir nebze de olsa moral vermeye çalıştık. Herkesin bir hikayesi var, ve bu hikayeler bazen bir tıraş koltuğunda ortaya çıkar. Bu özel anları sizinle paylaşmaktan mutluluk duyuyoruz.\n\n"Her küçük iyilik umut ışığıdır.\nizleyin,paylaşın,ilham olun"\n\nİYİ SEYİRLER..\n\ninstagram: https://www.instagram.com/barberstown\n\nhttps://www.instagram.com/barberstownisiklar\n\nhttps://www.instagram.com/barberstownetiler\n\nTiktok: https://www.tiktok.com/@barberstown\n\n\n\n#barber #shave #dégradé #fade #highfade #oldscissors #barberstown  #berber #traş #sakal #asmr'},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '5276',
#     'likeCount': '161',
#     'favoriteCount': '0',
#     'commentCount': '24'}},
#   {'kind': 'youtube#video',
#    'etag': 'qjkP5q7phOSiNGbzwhSbbAY043M',
#    'id': 'rZfgIX8i4JM',
#    'snippet': {'publishedAt': '2024-12-24T14:35:49Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen saç herşeyi değiştirir 😳💈 #barberstown #teambarberstown #barberstowntv',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/rZfgIX8i4JM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/rZfgIX8i4JM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/rZfgIX8i4JM/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/rZfgIX8i4JM/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/rZfgIX8i4JM/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen saç herşeyi değiştirir 😳💈 #barberstown #teambarberstown #barberstowntv',
#      'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '14913',
#     'likeCount': '330',
#     'favoriteCount': '0',
#     'commentCount': '2'}},
#   {'kind': 'youtube#video',
#    'etag': 'ZwbImcRb3OZkz865BHoDJrFHDhI',
#    'id': '18kYPQcuyqM',
#    'snippet': {'publishedAt': '2024-12-20T15:21:10Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen kaymak gibi 😳💈 #barberstown  #teambarberstown #barberstowntv',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/18kYPQcuyqM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/18kYPQcuyqM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/18kYPQcuyqM/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/18kYPQcuyqM/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/18kYPQcuyqM/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen kaymak gibi 😳💈 #barberstown  #teambarberstown #barberstowntv',
#      'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '5740',
#     'likeCount': '195',
#     'favoriteCount': '0',
#     'commentCount': '2'}},
#   {'kind': 'youtube#video',
#    'etag': 'Jt5g_2tgPq_3q2iw5RDsvi6spdg',
#    'id': 'x6SqEPB_ocw',
#    'snippet': {'publishedAt': '2024-12-19T14:50:57Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen şaşırırsın 😳💈 #barberstown #teambarberstown #barberstowntv',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/x6SqEPB_ocw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/x6SqEPB_ocw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/x6SqEPB_ocw/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/x6SqEPB_ocw/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/x6SqEPB_ocw/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen şaşırırsın 😳💈 #barberstown #teambarberstown #barberstowntv',
#      'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '15082',
#     'likeCount': '215',
#     'favoriteCount': '0',
#     'commentCount': '1'}},
#   {'kind': 'youtube#video',
#    'etag': '4i08VFOGcBb6LWZDT7NHD3Q4y_0',
#    'id': 'BZwQ-475WCk',
#    'snippet': {'publishedAt': '2024-12-16T15:31:37Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen güncellersin 😳💈 #barberstown',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BZwQ-475WCk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BZwQ-475WCk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BZwQ-475WCk/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/BZwQ-475WCk/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/BZwQ-475WCk/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen güncellersin 😳💈 #barberstown',
#      'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '5443',
#     'likeCount': '210',
#     'favoriteCount': '0',
#     'commentCount': '2'}},
#   {'kind': 'youtube#video',
#    'etag': 'VHZhzY6z0ySWzo4r_symM9EvdqU',
#    'id': 'Jf0ZLdh5n7k',
#    'snippet': {'publishedAt': '2024-12-16T10:59:52Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'DÜNYAYI ÇILDIRTAN ÜNLÜ TIRAŞ!!?',
#     'description': 'Özgüvenine yeniden kavuşmak isteyen bir dostumuzu ağırladık! Saç ve sakal stilinde yaptığımız değişimle, sadece dış görünüşü değil, enerjisini ve özgüvenini de yeniledik. Bu muhteşem dönüşümü adım adım izlemek için videoyu sonuna kadar izlemeyi unutmayın! Yeni bir tarz yeni bir başlangıç!\nİyi seyirler..\n\ninstagram: https://www.instagram.com/barberstown\n\nhttps://www.instagram.com/barberstownisiklar\n\nhttps://www.instagram.com/barberstownetiler\n\nTiktok: https://www.tiktok.com/@barberstown\n\n\n\n#barber #shave #dégradé #fade #highfade #oldscissors #barberstown  #berber #traş #sakal #asmr',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Jf0ZLdh5n7k/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Jf0ZLdh5n7k/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Jf0ZLdh5n7k/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/Jf0ZLdh5n7k/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/Jf0ZLdh5n7k/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'tags': ['barber',
#      'shave',
#      'fade',
#      'oldscissors',
#      'barberstown',
#      'berber',
#      'tıraş',
#      'traş',
#      'sakal',
#      'asma',
#      'berd',
#      'howto'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'DÜNYAYI ÇILDIRTAN ÜNLÜ TIRAŞ!!?',
#      'description': 'Özgüvenine yeniden kavuşmak isteyen bir dostumuzu ağırladık! Saç ve sakal stilinde yaptığımız değişimle, sadece dış görünüşü değil, enerjisini ve özgüvenini de yeniledik. Bu muhteşem dönüşümü adım adım izlemek için videoyu sonuna kadar izlemeyi unutmayın! Yeni bir tarz yeni bir başlangıç!\nİyi seyirler..\n\ninstagram: https://www.instagram.com/barberstown\n\nhttps://www.instagram.com/barberstownisiklar\n\nhttps://www.instagram.com/barberstownetiler\n\nTiktok: https://www.tiktok.com/@barberstown\n\n\n\n#barber #shave #dégradé #fade #highfade #oldscissors #barberstown  #berber #traş #sakal #asmr'},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '4707',
#     'likeCount': '186',
#     'favoriteCount': '0',
#     'commentCount': '25'}},
#   {'kind': 'youtube#video',
#    'etag': 'p0KL_j1XzIFisAtaZo9rm-g9gZY',
#    'id': 'kRj55k6_JMc',
#    'snippet': {'publishedAt': '2024-12-13T16:46:35Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen çıldırmamak elde değil 😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kRj55k6_JMc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/kRj55k6_JMc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/kRj55k6_JMc/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/kRj55k6_JMc/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/kRj55k6_JMc/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen çıldırmamak elde değil 😳💈',
#      'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '19375',
#     'likeCount': '258',
#     'favoriteCount': '0',
#     'commentCount': '2'}},
#   {'kind': 'youtube#video',
#    'etag': '_vftyKR2LBxTof24drqpGDheF14',
#    'id': 'LgUQ21vmD44',
#    'snippet': {'publishedAt': '2024-12-11T15:45:33Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen kaldırmak zorunda kalırsın 😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LgUQ21vmD44/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/LgUQ21vmD44/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/LgUQ21vmD44/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/LgUQ21vmD44/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/LgUQ21vmD44/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen kaldırmak zorunda kalırsın 😳💈',
#      'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '81849',
#     'likeCount': '1175',
#     'favoriteCount': '0',
#     'commentCount': '6'}},
#   {'kind': 'youtube#video',
#    'etag': 'TBZh7Fstas-Kxil2Kysbt-L1ONQ',
#    'id': 'cIIJX1ipb70',
#    'snippet': {'publishedAt': '2024-12-10T15:21:34Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen gözler anlatır 😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/cIIJX1ipb70/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/cIIJX1ipb70/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/cIIJX1ipb70/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/cIIJX1ipb70/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/cIIJX1ipb70/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen gözler anlatır 😳💈', 'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '8314',
#     'likeCount': '283',
#     'favoriteCount': '0',
#     'commentCount': '2'}},
#   {'kind': 'youtube#video',
#    'etag': 'EYQjnIlGB2LLozZrTQkQHHmlEfM',
#    'id': 'LIHSncXOSKE',
#    'snippet': {'publishedAt': '2024-12-05T15:27:16Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen pozisyon önemli 😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LIHSncXOSKE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/LIHSncXOSKE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/LIHSncXOSKE/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/LIHSncXOSKE/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/LIHSncXOSKE/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen pozisyon önemli 😳💈', 'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '11703',
#     'likeCount': '278',
#     'favoriteCount': '0',
#     'commentCount': '4'}},
#   {'kind': 'youtube#video',
#    'etag': '_aDChSsscg2Kisa7fUeC80YKkNs',
#    'id': 'g5q3R56EsT0',
#    'snippet': {'publishedAt': '2024-12-03T17:32:03Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen zorunda bırakırsın 😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/g5q3R56EsT0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/g5q3R56EsT0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/g5q3R56EsT0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/g5q3R56EsT0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/g5q3R56EsT0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen zorunda bırakırsın 😳💈', 'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '6548',
#     'likeCount': '241',
#     'favoriteCount': '0',
#     'commentCount': '3'}},
#   {'kind': 'youtube#video',
#    'etag': 'OTelWixfBADZ-DezLyvV6m1RrhY',
#    'id': 'pwMtiGcsr0k',
#    'snippet': {'publishedAt': '2024-11-30T18:51:00Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen yakalanırsın 😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pwMtiGcsr0k/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/pwMtiGcsr0k/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/pwMtiGcsr0k/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/pwMtiGcsr0k/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/pwMtiGcsr0k/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen yakalanırsın 😳💈', 'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '7304',
#     'likeCount': '179',
#     'favoriteCount': '0',
#     'commentCount': '0'}},
#   {'kind': 'youtube#video',
#    'etag': 'W1LvynrwlwetHxh4ApszvkpkjDY',
#    'id': 'jXOkbInft2Y',
#    'snippet': {'publishedAt': '2024-11-22T14:36:59Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'BU GÖRÜNTÜDEN BU HALE NASIL GELDİ? GÖZLERİNİZE İNANAMICAKSINIZ!!',
#     'description': 'Tıraş koltuğunda inanılmaz bir dönüşüm! Saç ve sakalı tamamen karmakarışık olan babamız, ustamızın yetenekleriyle yepyeni bir görünüme kavuştu. Bu videoda sadece tıraş değil, adeta bir sanat eseri izliceksiniz! Baştan sona muhteşem bir değişim sürecine tanık olmak için videoyu kaçırmayın. Sizce bu dönüşüm nasıl olmuş? Yorumlarda bizimle paylaşmayı unutmayın!\nİyi seyirler..\ninstagram: https://www.instagram.com/barberstown\n\nhttps://www.instagram.com/barberstownisiklar\n\nhttps://www.instagram.com/barberstownetiler\n\nTiktok: https://www.tiktok.com/@barberstown\n\n\n\n#barber #shave #dégradé #fade #highfade #oldscissors #barberstown  #berber #traş #sakal #asmr',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/jXOkbInft2Y/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/jXOkbInft2Y/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/jXOkbInft2Y/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/jXOkbInft2Y/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/jXOkbInft2Y/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'tags': ['barber',
#      'shave',
#      'fade',
#      'oldscissors',
#      'barberstown',
#      'berber',
#      'tıraş',
#      'traş',
#      'sakal',
#      'asma',
#      'berd',
#      'howto'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'BU GÖRÜNTÜDEN BU HALE NASIL GELDİ? GÖZLERİNİZE İNANAMICAKSINIZ!!',
#      'description': 'Tıraş koltuğunda inanılmaz bir dönüşüm! Saç ve sakalı tamamen karmakarışık olan babamız, ustamızın yetenekleriyle yepyeni bir görünüme kavuştu. Bu videoda sadece tıraş değil, adeta bir sanat eseri izliceksiniz! Baştan sona muhteşem bir değişim sürecine tanık olmak için videoyu kaçırmayın. Sizce bu dönüşüm nasıl olmuş? Yorumlarda bizimle paylaşmayı unutmayın!\nİyi seyirler..\ninstagram: https://www.instagram.com/barberstown\n\nhttps://www.instagram.com/barberstownisiklar\n\nhttps://www.instagram.com/barberstownetiler\n\nTiktok: https://www.tiktok.com/@barberstown\n\n\n\n#barber #shave #dégradé #fade #highfade #oldscissors #barberstown  #berber #traş #sakal #asmr'},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '12242',
#     'likeCount': '329',
#     'favoriteCount': '0',
#     'commentCount': '35'}},
#   {'kind': 'youtube#video',
#    'etag': '86peQbrbACj1cyhQ1ZdwQSYCIbo',
#    'id': 'Ew9tzZu_rdk',
#    'snippet': {'publishedAt': '2024-11-18T19:49:20Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen sıkışırsın 😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Ew9tzZu_rdk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Ew9tzZu_rdk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Ew9tzZu_rdk/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/Ew9tzZu_rdk/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/Ew9tzZu_rdk/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen sıkışırsın 😳💈', 'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '5573',
#     'likeCount': '169',
#     'favoriteCount': '0',
#     'commentCount': '2'}},
#   {'kind': 'youtube#video',
#    'etag': 'jtj8b6VtSfrRZQLCIEHHxMg6ISw',
#    'id': 'eQsH97jtJBI',
#    'snippet': {'publishedAt': '2024-11-17T11:55:42Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen yanlış oturursun vol2 😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/eQsH97jtJBI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/eQsH97jtJBI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/eQsH97jtJBI/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/eQsH97jtJBI/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/eQsH97jtJBI/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen yanlış oturursun vol2 😳💈',
#      'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '14191',
#     'likeCount': '384',
#     'favoriteCount': '0',
#     'commentCount': '4'}},
#   {'kind': 'youtube#video',
#    'etag': 'LbBO9O9fWtIFvIp9fojGW2pwTMQ',
#    'id': 'nMNmHZwE7f0',
#    'snippet': {'publishedAt': '2024-11-16T11:00:53Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'BOYACI GİBİ OTURDU, OYUNCU GİBİ KALKTI!! ŞİMDİ NETFLİX DÜŞÜNSÜN !?',
#     'description': 'Erkek için saçın ve sakalın en önemlisi bakımın ne kadar önemli olduğunu görebiliyorsunuz. (Öncesi ve Sonrası) yaptığımız videolarda en iyi işlerden biri oldu. Çok bişey söylemeye gerek yok başlayınca kopamıyorsun.\nİyi seyirler..\ninstagram: https://www.instagram.com/barberstown\n\nhttps://www.instagram.com/barberstownisiklar\n\nhttps://www.instagram.com/barberstownetiler\n\nTiktok: https://www.tiktok.com/@barberstown\n\n\n\n#barber #shave #dégradé #fade #highfade #oldscissors #barberstown  #berber #traş #sakal #asmr',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nMNmHZwE7f0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/nMNmHZwE7f0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/nMNmHZwE7f0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/nMNmHZwE7f0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/nMNmHZwE7f0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'tags': ['barber',
#      'shave',
#      'fade',
#      'oldscissors',
#      'barberstown',
#      'berber',
#      'tıraş',
#      'traş',
#      'sakal',
#      'asma',
#      'berd',
#      'howto'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'BOYACI GİBİ OTURDU, OYUNCU GİBİ KALKTI!! ŞİMDİ NETFLİX DÜŞÜNSÜN !?',
#      'description': 'Erkek için saçın ve sakalın en önemlisi bakımın ne kadar önemli olduğunu görebiliyorsunuz. (Öncesi ve Sonrası) yaptığımız videolarda en iyi işlerden biri oldu. Çok bişey söylemeye gerek yok başlayınca kopamıyorsun.\nİyi seyirler..\ninstagram: https://www.instagram.com/barberstown\n\nhttps://www.instagram.com/barberstownisiklar\n\nhttps://www.instagram.com/barberstownetiler\n\nTiktok: https://www.tiktok.com/@barberstown\n\n\n\n#barber #shave #dégradé #fade #highfade #oldscissors #barberstown  #berber #traş #sakal #asmr'},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '12033',
#     'likeCount': '335',
#     'favoriteCount': '0',
#     'commentCount': '33'}},
#   {'kind': 'youtube#video',
#    'etag': 'Zq4Ru4xhrIeNwqaHELh9OHnUrn8',
#    'id': 'edE0qe96mD0',
#    'snippet': {'publishedAt': '2024-11-10T08:58:41Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen tekrar yaparsın',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/edE0qe96mD0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/edE0qe96mD0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/edE0qe96mD0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/edE0qe96mD0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/edE0qe96mD0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen tekrar yaparsın', 'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '60814058',
#     'likeCount': '724647',
#     'favoriteCount': '0',
#     'commentCount': '641'}},
#   {'kind': 'youtube#video',
#    'etag': 'R5be1wtymzTU4XAOIeb5mYqEXnE',
#    'id': 'WmHVCSiXOYE',
#    'snippet': {'publishedAt': '2024-11-07T13:29:16Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen tazelersin @Marulkafaa 🤩 #marulkafa #teambarberstown #barberstowntv #barberstown',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/WmHVCSiXOYE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/WmHVCSiXOYE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/WmHVCSiXOYE/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/WmHVCSiXOYE/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/WmHVCSiXOYE/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen tazelersin @Marulkafaa 🤩 #marulkafa #teambarberstown #barberstowntv #barberstown',
#      'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '17241',
#     'likeCount': '594',
#     'favoriteCount': '0',
#     'commentCount': '6'}},
#   {'kind': 'youtube#video',
#    'etag': 'cSqri7jTLMOGtcIb7-xJT9h7O5w',
#    'id': 'awN8Avr_7J8',
#    'snippet': {'publishedAt': '2024-11-06T16:09:02Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'BU ADAMIN HAYATINI DEĞİŞTİREN SAÇ VE SAKAL KESİMİ! İNANILMAZ ÖNCESİ VE SONRASI',
#     'description': 'Bu videoda yalnız bir adamın saç ve sakal bakımını yaparak ona yeni bir görünüm kazandırıyoruz. Hayatını bir nebze olsun kolaylaştırmak, ona kendini iyi hissettirmek istedik. Siz de bu değişimin mucizesine tanık olun.\nİyi seyirler..\ninstagram: https://www.instagram.com/barberstown\n\nhttps://www.instagram.com/barberstownisiklar\n\nhttps://www.instagram.com/barberstownetiler\n\nTiktok: https://www.tiktok.com/@barberstown\n\n\n\n#barber #shave #dégradé #fade #highfade #oldscissors #barberstown  #berber #traş #sakal #asmr',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/awN8Avr_7J8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/awN8Avr_7J8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/awN8Avr_7J8/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/awN8Avr_7J8/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/awN8Avr_7J8/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'tags': ['barber',
#      'shave',
#      'fade',
#      'oldscissors',
#      'barberstown',
#      'berber',
#      'tıraş',
#      'traş',
#      'sakal',
#      'asma',
#      'berd',
#      'howto'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'BU ADAMIN HAYATINI DEĞİŞTİREN SAÇ VE SAKAL KESİMİ! İNANILMAZ ÖNCESİ VE SONRASI',
#      'description': 'Bu videoda yalnız bir adamın saç ve sakal bakımını yaparak ona yeni bir görünüm kazandırıyoruz. Hayatını bir nebze olsun kolaylaştırmak, ona kendini iyi hissettirmek istedik. Siz de bu değişimin mucizesine tanık olun.\nİyi seyirler..\ninstagram: https://www.instagram.com/barberstown\n\nhttps://www.instagram.com/barberstownisiklar\n\nhttps://www.instagram.com/barberstownetiler\n\nTiktok: https://www.tiktok.com/@barberstown\n\n\n\n#barber #shave #dégradé #fade #highfade #oldscissors #barberstown  #berber #traş #sakal #asmr'},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '12347',
#     'likeCount': '329',
#     'favoriteCount': '0',
#     'commentCount': '22'}},
#   {'kind': 'youtube#video',
#    'etag': 'dVMQs4o6x-BrOO_idt0Qr2ln2yE',
#    'id': 'hukCFudNNac',
#    'snippet': {'publishedAt': '2024-11-02T14:32:20Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen kendini görürsün😳💈',
#     'description': 'instagram: https://www.instagram.com/barberstown\n\nhttps://www.instagram.com/barberstownisiklar\n\nhttps://www.instagram.com/barberstownetiler\n\nTiktok: https://www.tiktok.com/@barberstown\n\n\n\n#barber #shave #dégradé #fade #highfade #oldscissors #barberstown  #berber #traş #sakal #asmr',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hukCFudNNac/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hukCFudNNac/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hukCFudNNac/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/hukCFudNNac/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/hukCFudNNac/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'tags': ['barber',
#      'shave',
#      'fade',
#      'oldscissors',
#      'barberstown',
#      'berber',
#      'tıraş',
#      'traş',
#      'sakal',
#      'asma',
#      'berd',
#      'howto'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen kendini görürsün😳💈',
#      'description': 'instagram: https://www.instagram.com/barberstown\n\nhttps://www.instagram.com/barberstownisiklar\n\nhttps://www.instagram.com/barberstownetiler\n\nTiktok: https://www.tiktok.com/@barberstown\n\n\n\n#barber #shave #dégradé #fade #highfade #oldscissors #barberstown  #berber #traş #sakal #asmr'},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '13338',
#     'likeCount': '602',
#     'favoriteCount': '0',
#     'commentCount': '4'}},
#   {'kind': 'youtube#video',
#    'etag': 'bjZe-zXW-QZyFycQwm0hrmNYyD0',
#    'id': 'L9dlyPgA1ws',
#    'snippet': {'publishedAt': '2024-10-19T16:40:02Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen saçlar anlatır😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/L9dlyPgA1ws/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/L9dlyPgA1ws/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/L9dlyPgA1ws/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/L9dlyPgA1ws/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/L9dlyPgA1ws/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen saçlar anlatır😳💈', 'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '18478',
#     'likeCount': '545',
#     'favoriteCount': '0',
#     'commentCount': '4'}},
#   {'kind': 'youtube#video',
#    'etag': 'XzzMA-8GmkyYIKAzDV7M8Di3I3c',
#    'id': 'NlEyMIPVx4E',
#    'snippet': {'publishedAt': '2024-10-17T11:03:51Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen soluk bir geçiş 😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/NlEyMIPVx4E/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/NlEyMIPVx4E/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/NlEyMIPVx4E/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/NlEyMIPVx4E/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/NlEyMIPVx4E/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen soluk bir geçiş 😳💈', 'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '24788',
#     'likeCount': '744',
#     'favoriteCount': '0',
#     'commentCount': '5'}},
#   {'kind': 'youtube#video',
#    'etag': 'jnA-_GZZr2TqQ1AhOVUSIxjgGos',
#    'id': 'sVEW0LS7yeQ',
#    'snippet': {'publishedAt': '2024-10-09T15:01:03Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'ÇATIDA YAŞAYAN ADAMI ZİYARET AKILLARA ZARAR BİR DEĞİŞİM!!?',
#     'description': 'Bitik bir halde. Birbirine karışmış bir saçtan kurtuluş eskimiş kıyafetlerden kurtuluş birlikte geçirilen keyifli saatler. Biraz da olsa toparlandık ayağı kalktık. Tekrar görüşmek üzere kalbi güzel kendi güzel adam.\nİyi seyirler...\n\ninstagram: https://www.instagram.com/barberstown\n\nhttps://www.instagram.com/barberstownisiklar\n\nhttps://www.instagram.com/barberstownetiler\n\nTiktok: https://www.tiktok.com/@barberstown\n\n\n\n#barber #shave #dégradé #fade #highfade #oldscissors #barberstown  #berber #traş #sakal #asmr',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sVEW0LS7yeQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/sVEW0LS7yeQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/sVEW0LS7yeQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/sVEW0LS7yeQ/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/sVEW0LS7yeQ/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'tags': ['barber',
#      'shave',
#      'fade',
#      'oldscissors',
#      'barberstown',
#      'berber',
#      'tıraş',
#      'traş',
#      'sakal',
#      'asma',
#      'berd',
#      'howto'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'ÇATIDA YAŞAYAN ADAMI ZİYARET AKILLARA ZARAR BİR DEĞİŞİM!!?',
#      'description': 'Bitik bir halde. Birbirine karışmış bir saçtan kurtuluş eskimiş kıyafetlerden kurtuluş birlikte geçirilen keyifli saatler. Biraz da olsa toparlandık ayağı kalktık. Tekrar görüşmek üzere kalbi güzel kendi güzel adam.\nİyi seyirler...\n\ninstagram: https://www.instagram.com/barberstown\n\nhttps://www.instagram.com/barberstownisiklar\n\nhttps://www.instagram.com/barberstownetiler\n\nTiktok: https://www.tiktok.com/@barberstown\n\n\n\n#barber #shave #dégradé #fade #highfade #oldscissors #barberstown  #berber #traş #sakal #asmr'},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '8872',
#     'likeCount': '304',
#     'favoriteCount': '0',
#     'commentCount': '32'}},
#   {'kind': 'youtube#video',
#    'etag': '5idGnopXMgEbJ6rMLNgPDf5woHk',
#    'id': 'g3FbRtYoN3I',
#    'snippet': {'publishedAt': '2024-10-07T20:32:38Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen yanları al üstler dağınık kalsın😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/g3FbRtYoN3I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/g3FbRtYoN3I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/g3FbRtYoN3I/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/g3FbRtYoN3I/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/g3FbRtYoN3I/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen yanları al üstler dağınık kalsın😳💈',
#      'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '12202',
#     'likeCount': '377',
#     'favoriteCount': '0',
#     'commentCount': '0'}},
#   {'kind': 'youtube#video',
#    'etag': 'W_qRr5B7urNWabLmA-VMcfs7B6A',
#    'id': 'VT8VJOM7Sg0',
#    'snippet': {'publishedAt': '2024-10-02T15:30:50Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen her saç modeli yakışır 😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VT8VJOM7Sg0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/VT8VJOM7Sg0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/VT8VJOM7Sg0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/VT8VJOM7Sg0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/VT8VJOM7Sg0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen her saç modeli yakışır 😳💈',
#      'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '17156',
#     'likeCount': '550',
#     'favoriteCount': '0',
#     'commentCount': '6'}},
#   {'kind': 'youtube#video',
#    'etag': 'XvTQg0skF_9tTuMbJoj-n-kiWRI',
#    'id': 'bP9Iu6pM9lM',
#    'snippet': {'publishedAt': '2024-09-17T17:14:43Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen 3 tıraş yersin😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/bP9Iu6pM9lM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/bP9Iu6pM9lM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/bP9Iu6pM9lM/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/bP9Iu6pM9lM/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/bP9Iu6pM9lM/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen 3 tıraş yersin😳💈', 'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '11778',
#     'likeCount': '302',
#     'favoriteCount': '0',
#     'commentCount': '2'}},
#   {'kind': 'youtube#video',
#    'etag': 'BvP_BXbJnNkX0JNipXtsxFLpJo0',
#    'id': 'IqZt3-DJPLs',
#    'snippet': {'publishedAt': '2024-08-27T16:16:37Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': '50 YAŞINA UYGUN SAÇ SAKAL MODELİ (Hair and Beard Styles Suitable for Age 50)',
#     'description': 'instagram: https://www.instagram.com/barberstown\n\nhttps://www.instagram.com/barberstownisiklar\n\nhttps://www.instagram.com/barberstownetiler\n\nTiktok: https://www.tiktok.com/@barberstown\n\n\n\n#barber #shave #dégradé #fade #highfade #oldscissors #barberstown  #berber #traş #sakal #asmr',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/IqZt3-DJPLs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/IqZt3-DJPLs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/IqZt3-DJPLs/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/IqZt3-DJPLs/sddefault.jpg',
#       'width': 640,
#       'height': 480}},
#     'channelTitle': 'Barberstown Tv',
#     'tags': ['barber',
#      'shave',
#      'fade',
#      'oldscissors',
#      'barberstown',
#      'berber',
#      'tıraş',
#      'traş',
#      'sakal',
#      'asma',
#      'berd',
#      'howto'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': '50 YAŞINA UYGUN SAÇ SAKAL MODELİ (Hair and Beard Styles Suitable for Age 50)',
#      'description': 'instagram: https://www.instagram.com/barberstown\n\nhttps://www.instagram.com/barberstownisiklar\n\nhttps://www.instagram.com/barberstownetiler\n\nTiktok: https://www.tiktok.com/@barberstown\n\n\n\n#barber #shave #dégradé #fade #highfade #oldscissors #barberstown  #berber #traş #sakal #asmr'},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '8918',
#     'likeCount': '248',
#     'favoriteCount': '0',
#     'commentCount': '14'}},
#   {'kind': 'youtube#video',
#    'etag': 'uNYZh6F4mOZ_CoCPjrUgq9waWRo',
#    'id': 'xxk4PEx_yRA',
#    'snippet': {'publishedAt': '2024-07-18T14:43:28Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'SAÇ BİR ERKEĞİN ELBİSESİ OLDUĞUNU GÖSTEREN BİR DEĞİŞİM!!?',
#     'description': 'Saçına değer veren ve takıntılı bir misafirdi zor oldu ama güzel oldu nice oldu profesyonel oldu iddialı bir saç modeli yakışıklı kardeşimize güzel dokunuşlar.\nİyi seyirler..\n\ninstagram: https://www.instagram.com/barberstown\n\nhttps://www.instagram.com/barberstownisiklar\n\nhttps://www.instagram.com/barberstownetiler\n\nTiktok: https://www.tiktok.com/@barberstown\n\n\n\n#barber #shave #dégradé #fade #highfade #oldscissors #barberstown  #berber #traş #sakal #asmr',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xxk4PEx_yRA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/xxk4PEx_yRA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/xxk4PEx_yRA/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/xxk4PEx_yRA/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/xxk4PEx_yRA/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
# ...
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen istersin 😳💈', 'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '28635',
#     'likeCount': '524',
#     'favoriteCount': '0',
#     'commentCount': '4'}},
#   {'kind': 'youtube#video',
#    'etag': 'W0K6bDHdhzw3soL_a1sxS4E7qWo',
#    'id': 'PDI5DL-IMJk',
#    'snippet': {'publishedAt': '2024-06-03T18:26:41Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen bağırırsın😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PDI5DL-IMJk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PDI5DL-IMJk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PDI5DL-IMJk/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/PDI5DL-IMJk/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/PDI5DL-IMJk/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen bağırırsın😳💈', 'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '23948',
#     'likeCount': '519',
#     'favoriteCount': '0',
#     'commentCount': '4'}},
#   {'kind': 'youtube#video',
#    'etag': '2MT9gnoZ3u-ZMRENZhQm7uEIUag',
#    'id': 'dmZaMYdUT_U',
#    'snippet': {'publishedAt': '2024-06-02T20:03:15Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen yanlış pozisyon😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/dmZaMYdUT_U/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/dmZaMYdUT_U/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/dmZaMYdUT_U/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/dmZaMYdUT_U/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/dmZaMYdUT_U/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen yanlış pozisyon😳💈', 'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '90293',
#     'likeCount': '1369',
#     'favoriteCount': '0',
#     'commentCount': '11'}},
#   {'kind': 'youtube#video',
#    'etag': 'RWvmnQEwRE7OqxC2j42JRot3IXc',
#    'id': 'ZLWKiocE1M0',
#    'snippet': {'publishedAt': '2024-05-29T14:46:48Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen kül olursun😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ZLWKiocE1M0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ZLWKiocE1M0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ZLWKiocE1M0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/ZLWKiocE1M0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/ZLWKiocE1M0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen kül olursun😳💈', 'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '21490',
#     'likeCount': '516',
#     'favoriteCount': '0',
#     'commentCount': '7'}},
#   {'kind': 'youtube#video',
#    'etag': 's3dy8AypHjN70j4KrsZw047O6k0',
#    'id': 'sCrj3OO2q_w',
#    'snippet': {'publishedAt': '2024-05-25T17:11:44Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen hiç değişmezsin😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sCrj3OO2q_w/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/sCrj3OO2q_w/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/sCrj3OO2q_w/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/sCrj3OO2q_w/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/sCrj3OO2q_w/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen hiç değişmezsin😳💈', 'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '11595',
#     'likeCount': '341',
#     'favoriteCount': '0',
#     'commentCount': '4'}},
#   {'kind': 'youtube#video',
#    'etag': 'm-J63EWoR5ZUH4HroBDg9k8Ee9I',
#    'id': 'efx8J_sK9GM',
#    'snippet': {'publishedAt': '2024-05-23T19:12:00Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen saçların senden vazgeçer 😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/efx8J_sK9GM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/efx8J_sK9GM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/efx8J_sK9GM/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/efx8J_sK9GM/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/efx8J_sK9GM/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen saçların senden vazgeçer 😳💈',
#      'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '24962',
#     'likeCount': '733',
#     'favoriteCount': '0',
#     'commentCount': '1'}},
#   {'kind': 'youtube#video',
#    'etag': 'UuUu1BOzG-1cfzv5Uve5PShpqW0',
#    'id': '-J3as-4a95Q',
#    'snippet': {'publishedAt': '2024-05-21T18:38:06Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen yakarsın 😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-J3as-4a95Q/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-J3as-4a95Q/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-J3as-4a95Q/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/-J3as-4a95Q/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/-J3as-4a95Q/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen yakarsın 😳💈', 'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '34495',
#     'likeCount': '532',
#     'favoriteCount': '0',
#     'commentCount': '2'}},
#   {'kind': 'youtube#video',
#    'etag': '9R9-uJLVQejbIwD2FKxLTsZcb4Q',
#    'id': 'ci-RAkiESXY',
#    'snippet': {'publishedAt': '2024-05-20T16:56:27Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen usturanın sessizliği 😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ci-RAkiESXY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ci-RAkiESXY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ci-RAkiESXY/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/ci-RAkiESXY/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/ci-RAkiESXY/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen usturanın sessizliği 😳💈', 'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '18511',
#     'likeCount': '466',
#     'favoriteCount': '0',
#     'commentCount': '5'}},
#   {'kind': 'youtube#video',
#    'etag': '5-UzsnneBa33HarbKs1Q0BrW7OI',
#    'id': 'L9VGtKArYaI',
#    'snippet': {'publishedAt': '2024-05-15T16:00:11Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen ıslanırsın 😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/L9VGtKArYaI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/L9VGtKArYaI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/L9VGtKArYaI/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/L9VGtKArYaI/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/L9VGtKArYaI/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen ıslanırsın 😳💈', 'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '26791',
#     'likeCount': '483',
#     'favoriteCount': '0',
#     'commentCount': '3'}},
#   {'kind': 'youtube#video',
#    'etag': 'PiOjewhkBJ_UH2fWBEGFQ04WSeM',
#    'id': 'r9mX0MoCjgY',
#    'snippet': {'publishedAt': '2024-05-10T15:00:09Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': '15 YAŞINDAKİ ÇOCUĞUN YAPTIĞI MUHTEŞEM DEĞİŞİM!!?',
#     'description': 'Muhteşem manzarada muhteşem bir adamla karşılaştık ve çok güzel zaman geçirdik.Patronumuz yoktu ama Kimin olduğu önemli değil bizim markamızın kalbinde var kalplere dokunmak elimizde yetiştirdiğimiz büyük adam yaptığı hareketle herkesi etkiledi. \n\ninstagram: https://www.instagram.com/barberstown\n\nhttps://www.instagram.com/barberstownisiklar\n\nhttps://www.instagram.com/barberstownetiler\n\nTiktok: https://www.tiktok.com/@barberstown\n\n\n\n#barber #shave #dégradé #fade #highfade #oldscissors #barberstown  #berber #traş #sakal #asmr',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/r9mX0MoCjgY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/r9mX0MoCjgY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/r9mX0MoCjgY/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/r9mX0MoCjgY/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/r9mX0MoCjgY/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'tags': ['barber',
#      'shave',
#      'fade',
#      'oldscissors',
#      'barberstown',
#      'berber',
#      'tıraş',
#      'traş',
#      'sakal',
#      'asma',
#      'berd',
#      'howto'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': '15 YAŞINDAKİ ÇOCUĞUN YAPTIĞI MUHTEŞEM DEĞİŞİM!!?',
#      'description': 'Muhteşem manzarada muhteşem bir adamla karşılaştık ve çok güzel zaman geçirdik.Patronumuz yoktu ama Kimin olduğu önemli değil bizim markamızın kalbinde var kalplere dokunmak elimizde yetiştirdiğimiz büyük adam yaptığı hareketle herkesi etkiledi. \n\ninstagram: https://www.instagram.com/barberstown\n\nhttps://www.instagram.com/barberstownisiklar\n\nhttps://www.instagram.com/barberstownetiler\n\nTiktok: https://www.tiktok.com/@barberstown\n\n\n\n#barber #shave #dégradé #fade #highfade #oldscissors #barberstown  #berber #traş #sakal #asmr'},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '20034',
#     'likeCount': '418',
#     'favoriteCount': '0',
#     'commentCount': '22'}},
#   {'kind': 'youtube#video',
#    'etag': 'O9qCogPyJBn5o2gXXgjIWQZ-2Vg',
#    'id': '-bZ-vpi7k-k',
#    'snippet': {'publishedAt': '2024-05-04T16:08:59Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen kaşın yarısı gider 😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-bZ-vpi7k-k/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-bZ-vpi7k-k/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-bZ-vpi7k-k/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/-bZ-vpi7k-k/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/-bZ-vpi7k-k/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen kaşın yarısı gider 😳💈', 'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '60709',
#     'likeCount': '571',
#     'favoriteCount': '0',
#     'commentCount': '10'}},
#   {'kind': 'youtube#video',
#    'etag': '-h3N3lKcQYldT63LDzY9gpkAFUg',
#    'id': 'XsY3cJoyUJE',
#    'snippet': {'publishedAt': '2024-05-03T18:31:39Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen parlatırsın 😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XsY3cJoyUJE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XsY3cJoyUJE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XsY3cJoyUJE/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/XsY3cJoyUJE/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/XsY3cJoyUJE/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen parlatırsın 😳💈', 'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '27185',
#     'likeCount': '900',
#     'favoriteCount': '0',
#     'commentCount': '7'}},
#   {'kind': 'youtube#video',
#    'etag': '6oowu-E8YEGUvSxvu8BymCS2PFw',
#    'id': 'GoeZmmKXi7k',
#    'snippet': {'publishedAt': '2024-05-02T15:28:15Z',
#     'channelId': 'UCUT1S-W5BIBUu_vzwhyGNVg',
#     'title': 'Bazen istemsiz eşlik edersin😳💈',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GoeZmmKXi7k/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/GoeZmmKXi7k/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/GoeZmmKXi7k/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/GoeZmmKXi7k/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/GoeZmmKXi7k/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Barberstown Tv',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bazen istemsiz eşlik edersin😳💈',
#      'description': ''},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '27981',
#     'likeCount': '576',
#     'favoriteCount': '0',
#     'commentCount': '3'}}],
#  'pageInfo': {'totalResults': 50, 'resultsPerPage': 50}}

# %%
def get_videos_details(youtube, video_ids):
  all_video_info = []
  for i in range(0, len(video_ids),50):
    request = youtube.videos().list(
        part = 'snippet,statistics',
        id = ','.join(video_ids[i:i+50])
    )
    response = request.execute()
    for videoId in range(len(response['items'])):
      video_stats = dict(
          Title = response['items'][videoId]['snippet']['title'],
          puplished_date = response['items'][videoId]['snippet']['publishedAt'],
          views = response['items'][videoId]['statistics']['viewCount'],
          likes = response['items'][videoId]['statistics']['likeCount'],
          #comments = response['items'][videoId]['statistics']['commentCount'],
          favorites = response['items'][videoId]['statistics']['favoriteCount'],
      )
      all_video_info.append(video_stats)

  return all_video_info

# %%
video_data = get_videos_details(youtube, video_ids)
video_data
# Out:
# [{'Title': 'Bazen aralara doğal dokunuş 😳💈',
#   'puplished_date': '2025-01-01T14:58:18Z',
#   'views': '7838',
#   'likes': '156',
#   'favorites': '0'},
#  {'Title': 'Bazen ders niteliğinde 😳💈',
#   'puplished_date': '2024-12-30T16:36:14Z',
#   'views': '3847',
#   'likes': '153',
#   'favorites': '0'},
#  {'Title': 'Bazen aralara 😳💈',
#   'puplished_date': '2024-12-27T14:38:07Z',
#   'views': '7158',
#   'likes': '148',
#   'favorites': '0'},
#  {'Title': 'SICACIK SOHBET EŞLİĞİNDE EVSİZ ADAMA YEPYENİ BİR GÖRÜNÜM!!?',
#   'puplished_date': '2024-12-26T08:51:44Z',
#   'views': '5276',
#   'likes': '161',
#   'favorites': '0'},
#  {'Title': 'Bazen saç herşeyi değiştirir 😳💈 #barberstown #teambarberstown #barberstowntv',
#   'puplished_date': '2024-12-24T14:35:49Z',
#   'views': '14913',
#   'likes': '330',
#   'favorites': '0'},
#  {'Title': 'Bazen kaymak gibi 😳💈 #barberstown  #teambarberstown #barberstowntv',
#   'puplished_date': '2024-12-20T15:21:10Z',
#   'views': '5740',
#   'likes': '195',
#   'favorites': '0'},
#  {'Title': 'Bazen şaşırırsın 😳💈 #barberstown #teambarberstown #barberstowntv',
#   'puplished_date': '2024-12-19T14:50:57Z',
#   'views': '15082',
#   'likes': '215',
#   'favorites': '0'},
#  {'Title': 'Bazen güncellersin 😳💈 #barberstown',
#   'puplished_date': '2024-12-16T15:31:37Z',
#   'views': '5443',
#   'likes': '210',
#   'favorites': '0'},
#  {'Title': 'DÜNYAYI ÇILDIRTAN ÜNLÜ TIRAŞ!!?',
#   'puplished_date': '2024-12-16T10:59:52Z',
#   'views': '4707',
#   'likes': '186',
#   'favorites': '0'},
#  {'Title': 'Bazen çıldırmamak elde değil 😳💈',
#   'puplished_date': '2024-12-13T16:46:35Z',
#   'views': '19375',
#   'likes': '258',
#   'favorites': '0'},
#  {'Title': 'Bazen kaldırmak zorunda kalırsın 😳💈',
#   'puplished_date': '2024-12-11T15:45:33Z',
#   'views': '81849',
#   'likes': '1175',
#   'favorites': '0'},
#  {'Title': 'Bazen gözler anlatır 😳💈',
#   'puplished_date': '2024-12-10T15:21:34Z',
#   'views': '8314',
#   'likes': '283',
#   'favorites': '0'},
#  {'Title': 'Bazen pozisyon önemli 😳💈',
#   'puplished_date': '2024-12-05T15:27:16Z',
#   'views': '11703',
#   'likes': '278',
#   'favorites': '0'},
#  {'Title': 'Bazen zorunda bırakırsın 😳💈',
#   'puplished_date': '2024-12-03T17:32:03Z',
#   'views': '6548',
#   'likes': '241',
#   'favorites': '0'},
#  {'Title': 'Bazen yakalanırsın 😳💈',
#   'puplished_date': '2024-11-30T18:51:00Z',
#   'views': '7304',
#   'likes': '179',
#   'favorites': '0'},
#  {'Title': 'BU GÖRÜNTÜDEN BU HALE NASIL GELDİ? GÖZLERİNİZE İNANAMICAKSINIZ!!',
#   'puplished_date': '2024-11-22T14:36:59Z',
#   'views': '12242',
#   'likes': '329',
#   'favorites': '0'},
#  {'Title': 'Bazen sıkışırsın 😳💈',
#   'puplished_date': '2024-11-18T19:49:20Z',
#   'views': '5573',
#   'likes': '169',
#   'favorites': '0'},
#  {'Title': 'Bazen yanlış oturursun vol2 😳💈',
#   'puplished_date': '2024-11-17T11:55:42Z',
#   'views': '14191',
#   'likes': '384',
#   'favorites': '0'},
#  {'Title': 'BOYACI GİBİ OTURDU, OYUNCU GİBİ KALKTI!! ŞİMDİ NETFLİX DÜŞÜNSÜN !?',
#   'puplished_date': '2024-11-16T11:00:53Z',
#   'views': '12033',
#   'likes': '335',
#   'favorites': '0'},
#  {'Title': 'Bazen tekrar yaparsın',
#   'puplished_date': '2024-11-10T08:58:41Z',
#   'views': '60814058',
#   'likes': '724647',
#   'favorites': '0'},
#  {'Title': 'Bazen tazelersin @Marulkafaa 🤩 #marulkafa #teambarberstown #barberstowntv #barberstown',
#   'puplished_date': '2024-11-07T13:29:16Z',
#   'views': '17241',
#   'likes': '594',
#   'favorites': '0'},
#  {'Title': 'BU ADAMIN HAYATINI DEĞİŞTİREN SAÇ VE SAKAL KESİMİ! İNANILMAZ ÖNCESİ VE SONRASI',
#   'puplished_date': '2024-11-06T16:09:02Z',
#   'views': '12347',
#   'likes': '329',
#   'favorites': '0'},
#  {'Title': 'Bazen kendini görürsün😳💈',
#   'puplished_date': '2024-11-02T14:32:20Z',
#   'views': '13338',
#   'likes': '602',
#   'favorites': '0'},
#  {'Title': 'Bazen saçlar anlatır😳💈',
#   'puplished_date': '2024-10-19T16:40:02Z',
#   'views': '18478',
#   'likes': '545',
#   'favorites': '0'},
#  {'Title': 'Bazen soluk bir geçiş 😳💈',
#   'puplished_date': '2024-10-17T11:03:51Z',
#   'views': '24788',
#   'likes': '744',
#   'favorites': '0'},
#  {'Title': 'ÇATIDA YAŞAYAN ADAMI ZİYARET AKILLARA ZARAR BİR DEĞİŞİM!!?',
#   'puplished_date': '2024-10-09T15:01:03Z',
#   'views': '8872',
#   'likes': '304',
#   'favorites': '0'},
#  {'Title': 'Bazen yanları al üstler dağınık kalsın😳💈',
#   'puplished_date': '2024-10-07T20:32:38Z',
#   'views': '12202',
#   'likes': '377',
#   'favorites': '0'},
#  {'Title': 'Bazen her saç modeli yakışır 😳💈',
#   'puplished_date': '2024-10-02T15:30:50Z',
#   'views': '17156',
#   'likes': '550',
#   'favorites': '0'},
#  {'Title': 'Bazen 3 tıraş yersin😳💈',
#   'puplished_date': '2024-09-17T17:14:43Z',
#   'views': '11778',
#   'likes': '302',
#   'favorites': '0'},
#  {'Title': '50 YAŞINA UYGUN SAÇ SAKAL MODELİ (Hair and Beard Styles Suitable for Age 50)',
#   'puplished_date': '2024-08-27T16:16:37Z',
#   'views': '8918',
#   'likes': '248',
#   'favorites': '0'},
#  {'Title': 'SAÇ BİR ERKEĞİN ELBİSESİ OLDUĞUNU GÖSTEREN BİR DEĞİŞİM!!?',
#   'puplished_date': '2024-07-18T14:43:28Z',
#   'views': '7633',
#   'likes': '203',
#   'favorites': '0'},
#  {'Title': 'Bazen kremin etkisini anlayamazsın😳💈',
#   'puplished_date': '2024-07-11T16:07:05Z',
#   'views': '20357',
#   'likes': '450',
#   'favorites': '0'},
#  {'Title': 'Bazen hızlı çözüm bulursun😳💈',
#   'puplished_date': '2024-06-19T15:06:56Z',
#   'views': '24861',
#   'likes': '685',
#   'favorites': '0'},
#  {'Title': 'Bazen özgüven patlaması yaşarsın 😳💈',
#   'puplished_date': '2024-06-13T14:54:29Z',
#   'views': '28456',
#   'likes': '901',
#   'favorites': '0'},
#  {'Title': 'Bazen durduramazsın 😳💈',
#   'puplished_date': '2024-06-09T15:08:55Z',
#   'views': '27500',
#   'likes': '659',
#   'favorites': '0'},
#  {'Title': 'Bazen boşluğuna gelir😳💈',
#   'puplished_date': '2024-06-08T14:06:14Z',
#   'views': '90553',
#   'likes': '1284',
#   'favorites': '0'},
#  {'Title': 'Bazen olmaması gereken olur😳💈',
#   'puplished_date': '2024-06-07T15:01:15Z',
#   'views': '36727',
#   'likes': '673',
#   'favorites': '0'},
#  {'Title': 'Bazen istersin 😳💈',
#   'puplished_date': '2024-06-06T16:44:23Z',
#   'views': '28635',
#   'likes': '524',
#   'favorites': '0'},
#  {'Title': 'Bazen bağırırsın😳💈',
#   'puplished_date': '2024-06-03T18:26:41Z',
#   'views': '23948',
#   'likes': '519',
#   'favorites': '0'},
#  {'Title': 'Bazen yanlış pozisyon😳💈',
#   'puplished_date': '2024-06-02T20:03:15Z',
#   'views': '90293',
#   'likes': '1369',
#   'favorites': '0'},
#  {'Title': 'Bazen kül olursun😳💈',
#   'puplished_date': '2024-05-29T14:46:48Z',
#   'views': '21490',
#   'likes': '516',
#   'favorites': '0'},
#  {'Title': 'Bazen hiç değişmezsin😳💈',
#   'puplished_date': '2024-05-25T17:11:44Z',
#   'views': '11595',
#   'likes': '341',
#   'favorites': '0'},
#  {'Title': 'Bazen saçların senden vazgeçer 😳💈',
#   'puplished_date': '2024-05-23T19:12:00Z',
#   'views': '24962',
#   'likes': '733',
#   'favorites': '0'},
#  {'Title': 'Bazen yakarsın 😳💈',
#   'puplished_date': '2024-05-21T18:38:06Z',
#   'views': '34495',
#   'likes': '532',
#   'favorites': '0'},
#  {'Title': 'Bazen usturanın sessizliği 😳💈',
#   'puplished_date': '2024-05-20T16:56:27Z',
#   'views': '18511',
#   'likes': '466',
#   'favorites': '0'},
#  {'Title': 'Bazen ıslanırsın 😳💈',
#   'puplished_date': '2024-05-15T16:00:11Z',
#   'views': '26791',
#   'likes': '483',
#   'favorites': '0'},
#  {'Title': '15 YAŞINDAKİ ÇOCUĞUN YAPTIĞI MUHTEŞEM DEĞİŞİM!!?',
#   'puplished_date': '2024-05-10T15:00:09Z',
#   'views': '20034',
#   'likes': '418',
#   'favorites': '0'},
#  {'Title': 'Bazen kaşın yarısı gider 😳💈',
#   'puplished_date': '2024-05-04T16:08:59Z',
#   'views': '60709',
#   'likes': '571',
#   'favorites': '0'},
#  {'Title': 'Bazen parlatırsın 😳💈',
#   'puplished_date': '2024-05-03T18:31:39Z',
#   'views': '27185',
#   'likes': '900',
#   'favorites': '0'},
#  {'Title': 'Bazen istemsiz eşlik edersin😳💈',
#   'puplished_date': '2024-05-02T15:28:15Z',
#   'views': '27981',
#   'likes': '576',
#   'favorites': '0'},
#  {'Title': 'Bazen yeni starlar çıkartırsın ortaya😳💈',
#   'puplished_date': '2024-05-01T11:40:19Z',
#   'views': '17551',
#   'likes': '529',
#   'favorites': '0'},
#  {'Title': 'Bazen eve erken gönderirsin 😳💈',
#   'puplished_date': '2024-04-06T15:13:33Z',
#   'views': '16243',
#   'likes': '529',
#   'favorites': '0'},
#  {'Title': 'Bazen beklediğim performans 😳💈',
#   'puplished_date': '2024-03-30T18:02:40Z',
#   'views': '32444',
#   'likes': '663',
#   'favorites': '0'},
#  {'Title': 'Bazen golden time 😳💈',
#   'puplished_date': '2024-03-28T14:46:09Z',
#   'views': '15426',
#   'likes': '479',
#   'favorites': '0'},
#  {'Title': 'Bazen saç sakal tıraş hizmeti alırsın😳💈',
#   'puplished_date': '2024-03-18T16:55:50Z',
#   'views': '15730',
#   'likes': '455',
#   'favorites': '0'},
#  {'Title': 'Bazen benzetirsin 😳💈',
#   'puplished_date': '2024-03-07T15:03:36Z',
#   'views': '23523',
#   'likes': '706',
#   'favorites': '0'},
#  {'Title': 'Bazen bir tebessüm yeter😳💈',
#   'puplished_date': '2024-02-29T10:25:20Z',
#   'views': '17012',
#   'likes': '833',
#   'favorites': '0'},
#  {'Title': 'EN DEĞERLİ VE EN GÜZEL TIRAŞ!!? (YÜZÜNDEKİ GÜLÜMSEME YETER) / THE MOST SPECİAL HAİR CUT',
#   'puplished_date': '2024-02-16T14:00:40Z',
#   'views': '17082',
#   'likes': '511',
#   'favorites': '0'},
#  {'Title': 'Bazen yamuk makasla düz kesersin😳💈',
#   'puplished_date': '2024-02-12T15:59:01Z',
#   'views': '26629',
#   'likes': '792',
#   'favorites': '0'},
#  {'Title': 'YAMUK MAKASLA DÜZ SAÇ NASIL KESİLİR!!? HOW TO CUT WITH BROKEN SCISSORS ASMR BARBER💈',
#   'puplished_date': '2024-02-10T15:08:58Z',
#   'views': '11214',
#   'likes': '252',
#   'favorites': '0'},
#  {'Title': 'Bazen yaşa değil başa bakarsın😳💈',
#   'puplished_date': '2024-02-06T14:36:31Z',
#   'views': '26581',
#   'likes': '842',
#   'favorites': '0'},
#  {'Title': 'Bazen çay istersin 😳💈',
#   'puplished_date': '2024-01-26T15:42:43Z',
#   'views': '33244',
#   'likes': '704',
#   'favorites': '0'},
#  {'Title': 'Bazen uyursun😳💈',
#   'puplished_date': '2024-01-17T14:31:34Z',
#   'views': '30611',
#   'likes': '558',
#   'favorites': '0'},
#  {'Title': 'OYUN OYNAMAKTAN SAÇINA BAŞINA DİKKAT ETMEYEN ÇOCUĞUN DEĞİŞİMİ!!?',
#   'puplished_date': '2024-01-14T11:00:32Z',
#   'views': '15883',
#   'likes': '379',
#   'favorites': '0'},
#  {'Title': 'Bazen ansızın gelir😳💈',
#   'puplished_date': '2024-01-12T19:02:01Z',
#   'views': '30971',
#   'likes': '688',
#   'favorites': '0'},
#  {'Title': 'Bazen gözünde canlanır 😳💈 @Marulkafaa 🤩',
#   'puplished_date': '2024-01-09T16:04:46Z',
#   'views': '105625',
#   'likes': '1632',
#   'favorites': '0'},
#  {'Title': 'Bazen usturanın ciddiyeti😳💈',
#   'puplished_date': '2024-01-02T15:01:14Z',
#   'views': '29601',
#   'likes': '778',
#   'favorites': '0'},
#  {'Title': 'Bazen dayanamazsın 😳💈',
#   'puplished_date': '2023-12-26T17:36:28Z',
#   'views': '35013',
#   'likes': '629',
#   'favorites': '0'},
#  {'Title': 'ASMR💈 2024 ÜN EN TREND EN KOLAY SAÇ MODELİ MULLET',
#   'puplished_date': '2023-12-24T14:00:43Z',
#   'views': '18655',
#   'likes': '413',
#   'favorites': '0'},
#  {'Title': 'Bazen vazgeçemezsin 😳💈',
#   'puplished_date': '2023-12-21T12:01:12Z',
#   'views': '18019',
#   'likes': '541',
#   'favorites': '0'},
#  {'Title': 'Bazen düşürürsün 😳💈',
#   'puplished_date': '2023-12-16T15:23:44Z',
#   'views': '46971',
#   'likes': '844',
#   'favorites': '0'},
#  {'Title': 'Bazen çıkamazsın 😳💈',
#   'puplished_date': '2023-12-06T14:59:54Z',
#   'views': '59243',
#   'likes': '1215',
#   'favorites': '0'},
#  {'Title': 'Bazen oturmayı öğrenirsin 😳💈',
#   'puplished_date': '2023-12-01T14:37:12Z',
#   'views': '57866500',
#   'likes': '537509',
#   'favorites': '0'},
#  {'Title': 'Bazen alev atarsın😳💈',
#   'puplished_date': '2023-11-26T17:24:48Z',
#   'views': '76464',
#   'likes': '1160',
#   'favorites': '0'},
#  {'Title': 'Bazen müşterinin istediği olur😳💈',
#   'puplished_date': '2023-11-20T17:48:24Z',
#   'views': '71419',
#   'likes': '1553',
#   'favorites': '0'},
#  {'Title': 'BU DEĞİŞİM SAYESİNDE KAYBETTİĞİ GENÇLİĞİNİ GERİ KAZANDI!!? & HE GAIN AGAIN HIS YOUTH THAT HE LOST',
#   'puplished_date': '2023-11-17T15:00:37Z',
#   'views': '806958',
#   'likes': '6680',
#   'favorites': '0'},
#  {'Title': 'Bazen çağ atlarsın😳💈',
#   'puplished_date': '2023-10-30T20:12:11Z',
#   'views': '60548',
#   'likes': '1773',
#   'favorites': '0'},
#  {'Title': 'Bazen kaymak gibi kesersin😳💈',
#   'puplished_date': '2023-10-26T16:13:08Z',
#   'views': '71939',
#   'likes': '2041',
#   'favorites': '0'},
#  {'Title': 'Bazen sende manikür yaptırırsın 😳💈',
#   'puplished_date': '2023-10-23T16:15:31Z',
#   'views': '39987',
#   'likes': '1190',
#   'favorites': '0'},
#  {'Title': 'Bazen olamazsın 😳💈',
#   'puplished_date': '2023-10-16T15:06:12Z',
#   'views': '178658',
#   'likes': '3539',
#   'favorites': '0'},
#  {'Title': 'Bazen göstermeden duramazsın 😳💈',
#   'puplished_date': '2023-10-10T14:36:10Z',
#   'views': '83073',
#   'likes': '1459',
#   'favorites': '0'},
#  {'Title': 'DEPRESYONA GİRMİŞ ADAM SAÇ MODELİ!!?',
#   'puplished_date': '2023-10-07T14:13:27Z',
#   'views': '19119',
#   'likes': '334',
#   'favorites': '0'},
#  {'Title': 'Bazen uçlarından aldırmak istersin 😳💈',
#   'puplished_date': '2023-09-29T15:32:05Z',
#   'views': '66504',
#   'likes': '1577',
#   'favorites': '0'},
#  {'Title': 'Bazen kim kesti bu saçı 😳💈',
#   'puplished_date': '2023-09-14T17:48:44Z',
#   'views': '102991',
#   'likes': '2433',
#   'favorites': '0'},
#  {'Title': 'Bazen kazıdık makaslarla 😳💈 @YouTube 🤩 1m 🙏🏻',
#   'puplished_date': '2023-09-11T18:10:17Z',
#   'views': '97361',
#   'likes': '2876',
#   'favorites': '0'},
#  {'Title': 'Bazen saçlarla konuşursun 😳💈',
#   'puplished_date': '2023-08-23T14:06:57Z',
#   'views': '92749',
#   'likes': '2197',
#   'favorites': '0'},
#  {'Title': 'Bazen maksimum doğum günü süprizi 😳🥳💈 en güzel hediye @YouTube  1m plaketi 🤩 teşekkürler🫶🏻',
#   'puplished_date': '2023-08-21T17:39:17Z',
#   'views': '117418100',
#   'likes': '879266',
#   'favorites': '0'},
#  {'Title': 'Bazen eski haline dönmek istemezsin 😳💈',
#   'puplished_date': '2023-08-17T18:38:38Z',
#   'views': '159582',
#   'likes': '4169',
#   'favorites': '0'},
#  {'Title': 'Bazen uyarman gerek 😳💈',
#   'puplished_date': '2023-08-16T16:09:55Z',
#   'views': '71508',
#   'likes': '2705',
#   'favorites': '0'},
#  {'Title': 'Bazen yanlış bağlarsın 😳💈',
#   'puplished_date': '2023-08-14T16:07:41Z',
#   'views': '25432478',
#   'likes': '314859',
#   'favorites': '0'},
#  {'Title': 'POPÇU BERKAY GİBİ GELDİ TOPÇU BERKAY GİBİ GİTTİ!!?',
#   'puplished_date': '2023-08-09T17:00:23Z',
#   'views': '21535',
#   'likes': '467',
#   'favorites': '0'},
#  {'Title': 'Bazen model renk aynısını istersin 😳💈',
#   'puplished_date': '2023-08-04T17:22:12Z',
#   'views': '144122',
#   'likes': '3748',
#   'favorites': '0'},
#  {'Title': 'Bazen aradığını bulursun 😳💈',
#   'puplished_date': '2023-08-03T18:55:41Z',
#   'views': '74184',
#   'likes': '2053',
#   'favorites': '0'},
#  {'Title': 'Bazen #antalyaspor 🤩',
#   'puplished_date': '2023-08-01T18:15:37Z',
#   'views': '57418',
#   'likes': '1625',
#   'favorites': '0'},
#  {'Title': 'Bazen denemeye değer😳💈',
#   'puplished_date': '2023-07-30T15:59:40Z',
#   'views': '96922',
#   'likes': '3192',
#   'favorites': '0'},
#  {'Title': 'Bazen özel damat tıraşı 😳💈',
#   'puplished_date': '2023-07-14T15:13:04Z',
#   'views': '93004',
#   'likes': '2881',
#   'favorites': '0'},
#  {'Title': 'Bazen 1m plaketini beklersin 😳💈',
#   'puplished_date': '2023-07-05T14:21:27Z',
#   'views': '50868',
#   'likes': '1798',
#   'favorites': '0'},
#  {'Title': 'Bazen yanan sen olursun 😳💈',
#   'puplished_date': '2023-07-04T15:26:56Z',
#   'views': '92093',
#   'likes': '1671',
#   'favorites': '0'},
#  {'Title': 'Bazen bunlar var 😳💈',
#   'puplished_date': '2023-06-29T09:04:46Z',
#   'views': '98148',
#   'likes': '2535',
#   'favorites': '0'},
#  {'Title': 'Bazen 3 e vurmak zorunda kalırsın 😳💈',
#   'puplished_date': '2023-06-27T18:34:40Z',
#   'views': '132192',
#   'likes': '2943',
#   'favorites': '0'},
#  {'Title': 'Bazen keser bakarsın 😳💈',
#   'puplished_date': '2023-06-23T17:20:53Z',
#   'views': '72991',
#   'likes': '2006',
#   'favorites': '0'},
#  {'Title': 'BUNA GERÇEKTEN İHTİYACI VARMIŞ! RESMEN EVRİM GEÇİRDİ!😯 | ASMR BARBER',
#   'puplished_date': '2023-06-19T16:20:32Z',
#   'views': '258351',
#   'likes': '2476',
#   'favorites': '0'},
#  {'Title': 'Bazen açmaman gerekir 😳💈',
#   'puplished_date': '2023-06-17T18:27:07Z',
#   'views': '85974',
#   'likes': '1848',
#   'favorites': '0'},
#  {'Title': 'Bazen benzeteceğin kişi bellidir 😳💈',
#   'puplished_date': '2023-06-13T15:08:37Z',
#   'views': '564123',
#   'likes': '14124',
#   'favorites': '0'},
#  {'Title': 'Bazen yanlış yıkatırsın 😳💈',
#   'puplished_date': '2023-06-03T17:47:23Z',
#   'views': '16361513',
#   'likes': '238458',
#   'favorites': '0'},
#  {'Title': 'Bazen beğenmek zorundasındır 😳💈',
#   'puplished_date': '2023-06-02T14:43:47Z',
#   'views': '138967',
#   'likes': '5390',
#   'favorites': '0'},
#  {'Title': 'Bazen emeğinin karşılığını alırsın 😳💈',
#   'puplished_date': '2023-05-29T16:25:34Z',
#   'views': '134148',
#   'likes': '4786',
#   'favorites': '0'},
#  {'Title': 'Bazen yanlış oturursun 😳💈',
#   'puplished_date': '2023-05-22T22:24:43Z',
#   'views': '507570337',
#   'likes': '6850736',
#   'favorites': '0'},
#  {'Title': 'Bazen duruş önemli 😳💈',
#   'puplished_date': '2023-05-18T16:54:52Z',
#   'views': '639250',
#   'likes': '10561',
#   'favorites': '0'},
#  {'Title': 'Bazen rahatlarsın 😳💈',
#   'puplished_date': '2023-05-17T13:56:31Z',
#   'views': '144865',
#   'likes': '5296',
#   'favorites': '0'},
#  {'Title': 'Bazen yargılamadan önce düşün 😳💈',
#   'puplished_date': '2023-05-15T17:38:54Z',
#   'views': '3443380',
#   'likes': '65060',
#   'favorites': '0'},
#  {'Title': 'SAÇ DÖKÜLMELERİNE KARŞI SAÇLARINI KAZITTI!!? /ASMR BARBER/',
#   'puplished_date': '2023-05-13T19:37:37Z',
#   'views': '42717',
#   'likes': '655',
#   'favorites': '0'},
#  {'Title': 'Bazen hayal edersin 😳💈',
#   'puplished_date': '2023-05-11T14:45:13Z',
#   'views': '103600',
#   'likes': '2477',
#   'favorites': '0'},
#  {'Title': 'Bazen zamanın nasıl geçtiğini anlamazsın 😳💈',
#   'puplished_date': '2023-05-03T18:29:48Z',
#   'views': '105454',
#   'likes': '3120',
#   'favorites': '0'},
#  {'Title': 'Bazen bir araya getirirsin 😳💈',
#   'puplished_date': '2023-05-02T23:17:13Z',
#   'views': '86589',
#   'likes': '2834',
#   'favorites': '0'},
#  {'Title': 'DÜĞÜN İÇİN 7 YILLIK SAÇLARINA VEDA ETTİ!!? & HE HAS CUT HİM 7 YEARS HAİR BECAUSE OF WEDDİNG',
#   'puplished_date': '2023-04-24T20:00:38Z',
#   'views': '67653',
#   'likes': '1158',
#   'favorites': '0'},
#  {'Title': 'Bazen aklına o gelir 😳💈',
#   'puplished_date': '2023-04-12T21:33:27Z',
#   'views': '103658',
#   'likes': '2465',
#   'favorites': '0'},
#  {'Title': 'Bazen yıkarlar 😳💈',
#   'puplished_date': '2023-03-24T18:18:31Z',
#   'views': '126960',
#   'likes': '2708',
#   'favorites': '0'},
#  {'Title': 'DÜZ VE UZUN SAÇLARI KESİNCE ORTAYA BONUS ÇIKTI!!?',
#   'puplished_date': '2023-03-18T09:00:22Z',
#   'views': '26518',
#   'likes': '600',
#   'favorites': '0'},
#  {'Title': 'AYNAYA BAKMAYA BAKMAYA KORKAR HALDEYDİ!!?',
#   'puplished_date': '2023-03-12T09:00:19Z',
#   'views': '32646',
#   'likes': '755',
#   'favorites': '0'},
#  {'Title': 'Bazen 6 yıllık saçları icardi modeline feda etti 😳💈',
#   'puplished_date': '2023-03-07T19:57:43Z',
#   'views': '109520',
#   'likes': '2524',
#   'favorites': '0'},
#  {'Title': "SOKAKTA YAŞAYAN ADAM ŞİMDİ HOLLYWOOD'A ADIM ATIYOR!!?",
#   'puplished_date': '2023-03-02T15:30:09Z',
#   'views': '936214',
#   'likes': '11921',
#   'favorites': '0'},
#  {'Title': 'Bazen 🔥👂',
#   'puplished_date': '2023-02-27T17:03:00Z',
#   'views': '130341',
#   'likes': '2803',
#   'favorites': '0'},
#  {'Title': 'Bazen 👍🏻😳💈',
#   'puplished_date': '2023-02-22T15:30:31Z',
#   'views': '185071',
#   'likes': '8137',
#   'favorites': '0'},
#  {'Title': "MAKASLA SAKAL KESTİRMEK İÇİN DUBAİ'DEN GELDİ!!? & COME FROM DUBAI TO CUT A BEARD WITH SCISSORS",
#   'puplished_date': '2023-02-20T18:27:08Z',
#   'views': '58867',
#   'likes': '996',
#   'favorites': '0'},
#  {'Title': "6 YILLIK SAÇLARI İCARDİ MODELİNE FEDA ETTİ!!? & HE GAVE UP 6 YEARS HAIR FOR ICARDI'S STYLE",
#   'puplished_date': '2023-02-05T09:00:11Z',
#   'views': '54669',
#   'likes': '1072',
#   'favorites': '0'},
#  {'Title': 'Bazen aşkın olayım 😳💈 #icardi 🤩',
#   'puplished_date': '2023-02-04T09:31:10Z',
#   'views': '352328',
#   'likes': '6724',
#   'favorites': '0'},
#  {'Title': 'Bazen yapamazsın derler 😳💈',
#   'puplished_date': '2023-02-02T18:31:05Z',
#   'views': '101572',
#   'likes': '3758',
#   'favorites': '0'},
#  {'Title': 'Bazen special 😳💈',
#   'puplished_date': '2023-01-30T20:23:00Z',
#   'views': '128685',
#   'likes': '5348',
#   'favorites': '0'},
#  {'Title': 'Bazen havalı girersin 😳💈',
#   'puplished_date': '2023-01-26T17:17:42Z',
#   'views': '165582',
#   'likes': '5870',
#   'favorites': '0'},
#  {'Title': 'Bazen yanlış anlarsın 😳💈',
#   'puplished_date': '2023-01-25T14:22:52Z',
#   'views': '118548',
#   'likes': '4203',
#   'favorites': '0'},
#  {'Title': 'Bazen gözlerini kaçıramazsın 😳💈',
#   'puplished_date': '2023-01-24T15:00:16Z',
#   'views': '153877',
#   'likes': '3166',
#   'favorites': '0'},
#  {'Title': 'Bazen uçlarından alırsın 😳💈',
#   'puplished_date': '2023-01-21T14:27:50Z',
#   'views': '102176',
#   'likes': '1924',
#   'favorites': '0'},
#  {'Title': 'Bazen kıyarsın 😳💈',
#   'puplished_date': '2022-12-26T19:01:54Z',
#   'views': '170244',
#   'likes': '4621',
#   'favorites': '0'},
#  {'Title': 'Bazen yeni şubede ilk tıraşı sen olursun 😳💈',
#   'puplished_date': '2022-12-22T14:25:10Z',
#   'views': '113636',
#   'likes': '4354',
#   'favorites': '0'},
#  {'Title': 'Bazen yürümeye devam edersin 😳💈',
#   'puplished_date': '2022-12-16T16:39:45Z',
#   'views': '95531',
#   'likes': '3185',
#   'favorites': '0'},
#  {'Title': 'Bazen yola çıkarsın 😳💈',
#   'puplished_date': '2022-12-13T15:10:56Z',
#   'views': '98250',
#   'likes': '3644',
#   'favorites': '0'},
#  {'Title': 'Bazen 61😳💈',
#   'puplished_date': '2022-12-07T16:44:59Z',
#   'views': '8539112',
#   'likes': '226203',
#   'favorites': '0'},
#  {'Title': 'Bazen sinirleriyle oynarsın 😳💈',
#   'puplished_date': '2022-11-30T11:35:17Z',
#   'views': '89316',
#   'likes': '2439',
#   'favorites': '0'},
#  {'Title': 'Bazen kendine bir yol çizersin 😳💈',
#   'puplished_date': '2022-11-29T12:38:57Z',
#   'views': '94037',
#   'likes': '1707',
#   'favorites': '0'},
#  {'Title': 'Bazen kendini tutamazsın 😳💈',
#   'puplished_date': '2022-11-28T13:55:32Z',
#   'views': '92590',
#   'likes': '2557',
#   'favorites': '0'},
#  {'Title': 'KURT ADAMA DÖNÜŞMEK ÜZEREYKEN İNSANA ÇEVİRDİK!!?',
#   'puplished_date': '2022-11-20T09:00:32Z',
#   'views': '28996',
#   'likes': '598',
#   'favorites': '0'},
#  {'Title': 'Bazen ters köşe 😳💈',
#   'puplished_date': '2022-11-19T15:49:01Z',
#   'views': '71543',
#   'likes': '2320',
#   'favorites': '0'},
#  {'Title': 'Bazen emek ister 😳💈',
#   'puplished_date': '2022-11-18T20:31:10Z',
#   'views': '84496',
#   'likes': '2502',
#   'favorites': '0'},
#  {'Title': 'Bazen icardiiii 😳💈',
#   'puplished_date': '2022-11-17T15:37:52Z',
#   'views': '60571',
#   'likes': '1324',
#   'favorites': '0'},
#  {'Title': "İCARDİNİN HAYRANIYIM DEDİ ONU İCARDİ YAPTIK! & HE WAS A ICARDI'S FAN, WE TURNED HIM ICARDI'S HIMSELF",
#   'puplished_date': '2022-11-16T14:59:56Z',
#   'views': '32998',
#   'likes': '562',
#   'favorites': '0'},
#  {'Title': 'Bazen güzel olaylara doğru yürürsün 😳💈',
#   'puplished_date': '2022-11-15T13:59:36Z',
#   'views': '68616',
#   'likes': '2809',
#   'favorites': '0'},
#  {'Title': 'Bazen sonrası 😳💈',
#   'puplished_date': '2022-11-14T15:44:13Z',
#   'views': '40384',
#   'likes': '1458',
#   'favorites': '0'},
#  {'Title': 'Bazen tek derdin saç kestirmek olur 😳💈',
#   'puplished_date': '2022-11-12T15:48:37Z',
#   'views': '129964',
#   'likes': '5580',
#   'favorites': '0'},
#  {'Title': 'KALEM SATAN GENÇ HAZİNE BULDU !? & YOUNG PEOPLE SELLING PENS FOUND TREASURE !',
#   'puplished_date': '2022-11-11T15:30:11Z',
#   'views': '20216',
#   'likes': '514',
#   'favorites': '0'},
#  {'Title': 'Bazen doğrular da yanıltır 😳💈',
#   'puplished_date': '2022-11-11T14:05:17Z',
#   'views': '96941',
#   'likes': '1636',
#   'favorites': '0'},
#  {'Title': 'Bazen değişim cesaret ister 😳💈',
#   'puplished_date': '2022-11-04T12:17:30Z',
#   'views': '95601',
#   'likes': '2610',
#   'favorites': '0'},
#  {'Title': 'Bazen bütün tuşlara basarsın 😳💈',
#   'puplished_date': '2022-11-02T15:23:32Z',
#   'views': '63034',
#   'likes': '1488',
#   'favorites': '0'},
#  {'Title': 'SAÇ SAKAL ESTETİĞİ YAPTIK!!? & WE DID HIM HAIR AND BEARD PLASTIC SURGERY',
#   'puplished_date': '2022-10-28T16:52:20Z',
#   'views': '24625',
#   'likes': '606',
#   'favorites': '0'},
#  {'Title': 'Bazen boyunda büyük kararlar alırsın 😳💈',
#   'puplished_date': '2022-10-26T16:38:31Z',
#   'views': '82727',
#   'likes': '3294',
#   'favorites': '0'},
#  {'Title': 'HAMİLE KARISINI KIRMADI VE SAÇLARA VEDA ETTİ!!? & HE LISTEN TO HIS WIFE AND SAID GOODBYE TO HIS HAIR',
#   'puplished_date': '2022-10-22T21:00:09Z',
#   'views': '28299',
#   'likes': '621',
#   'favorites': '0'},
#  {'Title': 'Bazen gözler anlatır 😳💈',
#   'puplished_date': '2022-10-21T15:30:02Z',
#   'views': '64882',
#   'likes': '2832',
#   'favorites': '0'},
#  {'Title': 'BU TIRAŞI YAPAN KÖR , YAPTIRAN DA AŞIK OLDU!!?',
#   'puplished_date': '2022-10-18T15:24:32Z',
#   'views': '13429',
#   'likes': '356',
#   'favorites': '0'},
#  {'Title': 'Bazen gerçek olduğuna inanamazsın 😳💈',
#   'puplished_date': '2022-10-16T12:47:46Z',
#   'views': '41750',
#   'likes': '1323',
#   'favorites': '0'},
#  {'Title': 'ADAMIN KAFAYA UZAYLI İNDİRDİK!? & WE LANDED ON HIS HAD A ALIEN ?!',
#   'puplished_date': '2022-10-12T15:00:12Z',
#   'views': '13266',
#   'likes': '318',
#   'favorites': '0'},
#  {'Title': 'Bazen takılır kalırsın 😳💈',
#   'puplished_date': '2022-10-11T12:26:26Z',
#   'views': '65862',
#   'likes': '1925',
#   'favorites': '0'},
#  {'Title': 'Bazen manzaraya karşı 😳💈',
#   'puplished_date': '2022-10-10T16:22:33Z',
#   'views': '16355686',
#   'likes': '740187',
#   'favorites': '0'},
#  {'Title': 'Bazen çeker bırakırsın 😳💈',
#   'puplished_date': '2022-10-08T10:10:51Z',
#   'views': '39625',
#   'likes': '1145',
#   'favorites': '0'},
#  {'Title': "BU SAÇ MODELİNİ FÖN ÇEKMEDEN KULLANAMAZSIN!! & WİTHOUT BLOW DRİYİNG YOU CAN'T USE THİS HAİRSTYLE",
#   'puplished_date': '2022-10-05T14:09:34Z',
#   'views': '16111',
#   'likes': '456',
#   'favorites': '0'},
#  {'Title': 'KENDİNİ SALMIŞ BİR ÇOCUĞA NEFES ALDIRDIK!!? & WE GET RID OF HIS MESSY LOOK!!',
#   'puplished_date': '2022-10-02T09:00:06Z',
#   'views': '15905',
#   'likes': '462',
#   'favorites': '0'},
#  {'Title': 'Bazen yön verirsin 😳💈',
#   'puplished_date': '2022-09-30T09:13:35Z',
#   'views': '98306',
#   'likes': '3891',
#   'favorites': '0'},
#  {'Title': 'ÖLÇTÜK BİÇTİK EN ÇILGIN MODELİ TASARLADIK!! & WE DO IT CRAZIEST MODEL EVER',
#   'puplished_date': '2022-09-28T16:07:44Z',
#   'views': '121549',
#   'likes': '1550',
#   'favorites': '0'},
#  {'Title': 'Bazen saçın altından şeytan çıkar 😳💈',
#   'puplished_date': '2022-09-27T19:37:05Z',
#   'views': '70989',
#   'likes': '2883',
#   'favorites': '0'},
#  {'Title': 'Bazen kurtarırsın 😳💈',
#   'puplished_date': '2022-09-26T19:50:28Z',
#   'views': '328408',
#   'likes': '8893',
#   'favorites': '0'},
#  {'Title': 'EVSİZ AMCANIN ÇATIDA TIRAŞI!!? (HAYALDİ GERÇEK OLDU) & WE GAVE HOMELESS A HAIRCUT ON ROOFTOP',
#   'puplished_date': '2022-09-25T09:00:03Z',
#   'views': '108944',
#   'likes': '2182',
#   'favorites': '0'},
#  {'Title': 'Bazen şaşırırsın 😳💈',
#   'puplished_date': '2022-09-24T20:00:27Z',
#   'views': '64098',
#   'likes': '1509',
#   'favorites': '0'},
#  {'Title': 'Bazen babayı gençliğine götürürsün 😳💈',
#   'puplished_date': '2022-09-23T17:46:21Z',
#   'views': '672747',
#   'likes': '16750',
#   'favorites': '0'},
#  {'Title': 'BEKLENMEDİK BİR ANDA SAÇINI KESTİRME KARARI ALDI!!? (UZUN SAÇIN ÖMRÜ KISA SÜRDÜ)',
#   'puplished_date': '2022-09-22T15:12:18Z',
#   'views': '25196',
#   'likes': '667',
#   'favorites': '0'},
#  {'Title': 'Bazen aradığın boyayı bulursun 😳💈',
#   'puplished_date': '2022-09-20T17:10:34Z',
#   'views': '54817',
#   'likes': '3282',
#   'favorites': '0'},
#  {'Title': 'SAÇININ ALTINDAN ŞEYTAN ÇIKTI!!? & HE HIDING A DEVIL UNDER HIS HAIR!',
#   'puplished_date': '2022-09-18T09:00:24Z',
#   'views': '17120',
#   'likes': '524',
#   'favorites': '0'},
#  {'Title': "40 YILDIR BERBERİM BÖYLE BİR DEĞİŞİM GÖRMEDİM!?! & I HAVEN'T SEEN SUCH A CHANGE İN 40 YEARS!!",
#   'puplished_date': '2022-09-14T14:00:07Z',
#   'views': '55828',
#   'likes': '1152',
#   'favorites': '0'},
#  {'Title': 'BU SAÇ BABAMI GENÇLİĞİNE GÖTÜRDÜ!!? (80LER, 90LAR) & THIS HAIRCUT TURN BACK OUR FATHER THE HIS YOUTH',
#   'puplished_date': '2022-09-11T09:00:08Z',
#   'views': '40090',
#   'likes': '874',
#   'favorites': '0'},
#  {'Title': 'Bazen denersin 😳💈',
#   'puplished_date': '2022-09-09T18:44:55Z',
#   'views': '60253',
#   'likes': '2193',
#   'favorites': '0'},
#  {'Title': 'EKİBİMDEN EN GENÇ KALFAYA TIRAŞ OLDUM!!? (DAHA 16 YAŞINDAA!!) & HE IS ONLY 16 YEARS OLD BARBER !!?',
#   'puplished_date': '2022-09-07T15:27:01Z',
#   'views': '114456',
#   'likes': '2070',
#   'favorites': '0'},
#  {'Title': 'BAZEN AÇIM DAYIYI BULURSUN 😳💈',
#   'puplished_date': '2022-09-02T16:12:29Z',
#   'views': '186521',
#   'likes': '7282',
#   'favorites': '0'},
#  {'Title': "KADINLARIN BAYILDIĞI SAÇ RENGİNİ YAPTIK!! | WOMEN'S FAVORITE HAIR COLOR ON MEN !",
#   'puplished_date': '2022-08-28T09:00:16Z',
#   'views': '15176',
#   'likes': '529',
#   'favorites': '0'},
#  {'Title': 'KAFASI ÇOK KARIŞIKTI ARTIK DÜM DÜZ!! | CURLY HAIR? NO PROBLEM!',
#   'puplished_date': '2022-08-24T15:00:08Z',
#   'views': '13630',
#   'likes': '443',
#   'favorites': '0'},
#  {'Title': 'ZATEN YAKIŞIKLIYDI DAHA YAKIŞIKLI OLDU!!? & HE WAS ALREADY HANDSOME, BECOME MORE HANDSOME / ASMR💈',
#   'puplished_date': '2022-08-21T11:06:34Z',
#   'views': '18761',
#   'likes': '557',
#   'favorites': '0'},
#  {'Title': 'Bazen sulu şaka yaparsın 😳💈',
#   'puplished_date': '2022-08-20T14:26:05Z',
#   'views': '72648',
#   'likes': '1756',
#   'favorites': '0'},
#  {'Title': 'BAZEN GERGİN 😳💈',
#   'puplished_date': '2022-08-18T15:15:23Z',
#   'views': '61563',
#   'likes': '1292',
#   'favorites': '0'},
#  {'Title': 'ASMR💈KOCA SAKAL TIRAŞA GELDİ ! | BIG BEARD IS HERE !',
#   'puplished_date': '2022-08-17T15:03:48Z',
#   'views': '41147',
#   'likes': '893',
#   'favorites': '0'},
#  {'Title': 'AÇIM DAYININ HİKAYESİNİ ÖĞRENDİK!!? & WE HOST THE HOMELESS MAN AND GIVE HIM A GOOD DAY',
#   'puplished_date': '2022-08-14T11:00:13Z',
#   'views': '116133',
#   'likes': '2795',
#   'favorites': '0'},
#  {'Title': 'MAĞARA ADAMINDAN CENTİLMENE DÖNÜŞÜM ! | HOW TO CHANGE CAVEMAN TO GENTLEMAN ?',
#   'puplished_date': '2022-08-10T15:00:21Z',
#   'views': '23424',
#   'likes': '693',
#   'favorites': '0'},
#  {'Title': 'Bazen yaşamadan bilemezsin 😳💈',
#   'puplished_date': '2022-08-08T08:34:54Z',
#   'views': '65513',
#   'likes': '1673',
#   'favorites': '0'},
#  {'Title': 'ASMR 💈GELECEĞE YÖN VERECEK SAÇ MODELİ (2049) | HAIRSTYLE THAT COME FROM THE FUTURE (2049)',
#   'puplished_date': '2022-08-07T09:00:29Z',
#   'views': '36566',
#   'likes': '902',
#   'favorites': '0'},
#  {'Title': 'Bazen Olması Gereken Yapılır😳💈 #teambarberstown #barberstowntv #barberstown',
#   'puplished_date': '2022-08-05T17:19:20Z',
#   'views': '61310',
#   'likes': '2386',
#   'favorites': '0'},
#  {'Title': '10 YILLIK SAÇLARIN ALTINDAN NE ÇIKTI ? | WHAT IS HE HIDING HIS 10 YEARS OLD HAIRS?',
#   'puplished_date': '2022-08-03T15:00:42Z',
#   'views': '126859',
#   'likes': '1598',
#   'favorites': '0'},
#  {'Title': 'ASMR 💈SAÇ TIRAŞI BİR İNSANI NE KADAR DEĞİŞTİREBİLİR ? (İNANILMAZ DEĞİŞİM) | AMAZING CHANGE !',
#   'puplished_date': '2022-07-31T09:00:01Z',
#   'views': '35699',
#   'likes': '752',
#   'favorites': '0'},
#  {'Title': 'Bazen Before & After 😳💈',
#   'puplished_date': '2022-07-29T16:48:13Z',
#   'views': '52553',
#   'likes': '1548',
#   'favorites': '0'},
#  {'Title': 'ASMR💈UZUN SAÇLARINI KESTİREREK HAYATININ HATASINI MI YAPTI ? | DID HE CHOOSE THE RIGHT DECISION ?',
#   'puplished_date': '2022-07-27T15:00:11Z',
#   'views': '82234',
#   'likes': '1550',
#   'favorites': '0'},
#  {'Title': 'Bazen sersemletir 😳💈 #teambarberstown #barberstowntv #barberstown',
#   'puplished_date': '2022-07-23T15:55:27Z',
#   'views': '60080',
#   'likes': '2644',
#   'favorites': '0'},
#  {'Title': 'Bazen OYUN oynarsın 😳💈',
#   'puplished_date': '2022-07-16T17:36:26Z',
#   'views': '72565',
#   'likes': '3436',
#   'favorites': '0'},
#  {'Title': 'BİRBİRİNE GİRMİŞ SAÇLARA NE Mİ OLDU!!? & WHAT HAPPENED TO HIS HAİR THAT WAS TANGLED LIKE THAT!!?',
#   'puplished_date': '2022-07-10T09:00:21Z',
#   'views': '119425',
#   'likes': '1733',
#   'favorites': '0'},
#  {'Title': 'Bazen ya bi değişiklik olsun bıktık ya 😳💈 #teambarberstown #barberstowntv #barberstown 👈🏻',
#   'puplished_date': '2022-07-06T16:29:17Z',
#   'views': '62522',
#   'likes': '2476',
#   'favorites': '0'},
#  {'Title': 'ASMR BARBER 💈10 YILLIK SAÇLARINDAN VAZ MI GEÇTİ ? | HAS HE GIVEN UP ON HIS 10 YEARS OLD HAIR ?',
#   'puplished_date': '2022-07-03T09:00:12Z',
#   'views': '99262',
#   'likes': '1998',
#   'favorites': '0'},
#  {'Title': 'HİNT PRENSİNİN İNANILMAZ DEĞİŞİMİ | THE AMAZING CHANGE OF THE RAJA OF INDIA',
#   'puplished_date': '2022-06-29T15:00:13Z',
#   'views': '28534',
#   'likes': '763',
#   'favorites': '0'},
#  {'Title': 'Bazen uzatmaya gerek yok 😳💈 #teambarberstown #barberstown  #barberstowntv',
#   'puplished_date': '2022-06-28T18:02:11Z',
#   'views': '1857416',
#   'likes': '74970',
#   'favorites': '0'},
#  {'Title': 'İLK ALMAN İMPARATORU 1.WİLHELM TIRAŞI | FIRST GERMAN KAISER I.WILHELM SHAVE',
#   'puplished_date': '2022-06-26T09:00:30Z',
#   'views': '37778',
#   'likes': '813',
#   'favorites': '0'},
#  {'Title': 'Bazen dublör kullanırsın😳💈 #teambarberstown #barberstown #barberstowntv',
#   'puplished_date': '2022-06-25T15:59:52Z',
#   'views': '3674124',
#   'likes': '80600',
#   'favorites': '0'},
#  {'Title': 'Bazen tam istediğin gibi 😳💈#teambarberstown #barberstown #barberstowntv',
#   'puplished_date': '2022-06-24T15:25:18Z',
#   'views': '105197',
#   'likes': '3758',
#   'favorites': '0'},
#  {'Title': 'Bazen benzetirsin 😳💈',
#   'puplished_date': '2022-06-21T14:25:49Z',
#   'views': '48100',
#   'likes': '2416',
#   'favorites': '0'},
#  {'Title': 'Bazen geride bırakırsın 😳💈',
#   'puplished_date': '2022-06-18T17:10:42Z',
#   'views': '50571',
#   'likes': '2422',
#   'favorites': '0'},
#  {'Title': 'Bazen tıraş uzun sürer😳💈',
#   'puplished_date': '2022-06-17T14:25:15Z',
#   'views': '64216',
#   'likes': '1455',
#   'favorites': '0'},
#  {'Title': "BİR GÜNDE HAYAT NASIL DEĞİŞİR! & HOW CAN YOU CHANGE HOMELESS MAN'S LİFE IN A ONE DAY?",
#   'puplished_date': '2022-06-15T15:00:06Z',
#   'views': '57123',
#   'likes': '1996',
#   'favorites': '0'},
#  {'Title': 'Bazen tek atarsın 😳💈',
#   'puplished_date': '2022-06-13T18:05:53Z',
#   'views': '27696935',
#   'likes': '520579',
#   'favorites': '0'},
#  {'Title': 'KAFASINDAKİ YARA İZİNDEN KRAL YOLU YAPTIK | WE TURNED HIS SCAR TO PERSIAN ROYAL ROAD',
#   'puplished_date': '2022-06-12T10:01:53Z',
#   'views': '20660',
#   'likes': '579',
#   'favorites': '0'},
#  {'Title': 'Bazen dünya boştur lo 😳💈',
#   'puplished_date': '2022-06-10T16:58:42Z',
#   'views': '71138',
#   'likes': '1370',
#   'favorites': '0'},
#  {'Title': 'Bazen bunu yaşarsın 😳💈',
#   'puplished_date': '2022-06-09T18:27:31Z',
#   'views': '63008',
#   'likes': '1653',
#   'favorites': '0'},
#  {'Title': 'Bazen kalanlarda gider!😳💈',
#   'puplished_date': '2022-06-07T14:36:08Z',
#   'views': '93302',
#   'likes': '3396',
#   'favorites': '0'},
#  {'Title': 'Bazen küçüğü büyük kesersin 😳💈',
#   'puplished_date': '2022-06-03T14:55:07Z',
#   'views': '78031',
#   'likes': '3340',
#   'favorites': '0'},
#  {'Title': 'YÜKSEK GEÇİŞ TIRAŞI NASIL YAPILIR 💈 HOW TO DO A HIGH FADE',
#   'puplished_date': '2022-06-01T15:00:03Z',
#   'views': '29725',
#   'likes': '816',
#   'favorites': '0'},
#  {'Title': 'Bazen beklediğine değer 😳💈',
#   'puplished_date': '2022-05-31T14:20:50Z',
#   'views': '94361',
#   'likes': '4167',
#   'favorites': '0'},
#  {'Title': 'Bazen yaşa değil icraata bakarsın 😳💈',
#   'puplished_date': '2022-05-26T17:11:24Z',
#   'views': '79495',
#   'likes': '3399',
#   'favorites': '0'},
#  {'Title': 'EVSİZ İKİ KARDEŞ YILLAR SONRA BİR ARADA ! | TWO HOMELESS BROTHERS ARE TOGETHER AGAIN AFTER YEARS',
#   'puplished_date': '2022-05-25T16:02:17Z',
#   'views': '57914',
#   'likes': '1640',
#   'favorites': '0'},
#  {'Title': 'Bazen çift çizgi 😳💈',
#   'puplished_date': '2022-05-24T16:29:17Z',
#   'views': '92692',
#   'likes': '2211',
#   'favorites': '0'},
#  {'Title': "DÜNYANIN EN UZUN BIYIK TASARIMI!! & THE WORLD'S LONGEST MUSTACHE DESİGN",
#   'puplished_date': '2022-05-22T09:00:25Z',
#   'views': '49628',
#   'likes': '951',
#   'favorites': '0'},
#  {'Title': 'Bazen tercihin doğru olur 😳💈',
#   'puplished_date': '2022-05-17T16:11:20Z',
#   'views': '328285',
#   'likes': '10030',
#   'favorites': '0'},
#  {'Title': 'Bazen gidemezsin 😳💈',
#   'puplished_date': '2022-05-15T15:28:28Z',
#   'views': '136626',
#   'likes': '6768',
#   'favorites': '0'},
#  {'Title': 'Bazen Spiderman 😳💈',
#   'puplished_date': '2022-05-14T12:40:33Z',
#   'views': '70469',
#   'likes': '3892',
#   'favorites': '0'},
#  {'Title': 'Bazen derdine derman olursun😳💈',
#   'puplished_date': '2022-05-11T18:06:53Z',
#   'views': '100447',
#   'likes': '5445',
#   'favorites': '0'},
#  {'Title': 'Bazen bunu yaşarsın 🥺💈',
#   'puplished_date': '2022-05-10T18:07:27Z',
#   'views': '81400',
#   'likes': '3213',
#   'favorites': '0'},
#  {'Title': 'Bazen havalı 😳💈',
#   'puplished_date': '2022-05-09T14:27:31Z',
#   'views': '79353',
#   'likes': '4033',
#   'favorites': '0'},
#  {'Title': "AĞDANIN KILLA İMTİHANI ! (ŞAŞIRTAN DEĞİŞİM) | EVEN WAX DIDN'T HELP HIM ?! (AMAZING CHANGE)",
#   'puplished_date': '2022-05-08T09:00:04Z',
#   'views': '147660',
#   'likes': '2551',
#   'favorites': '0'},
#  {'Title': 'Bazen işler kesattır 😳💈',
#   'puplished_date': '2022-05-07T17:26:44Z',
#   'views': '68983',
#   'likes': '2249',
#   'favorites': '0'},
#  {'Title': 'Bazen gizem yüklersin 😳💈',
#   'puplished_date': '2022-05-05T15:44:57Z',
#   'views': '95942',
#   'likes': '4017',
#   'favorites': '0'},
#  {'Title': 'Bazen paylaşmaya kıyamazsın 😳💈',
#   'puplished_date': '2022-05-03T14:31:04Z',
#   'views': '361353',
#   'likes': '22160',
#   'favorites': '0'},
#  {'Title': 'SOKAK ADAMINA BAYRAM HEDİYESİ (İNANILMAZ DEĞİŞİM) | HOLIDAY GIFT TO HOMELESS MAN (AMAZING CHANGE)',
#   'puplished_date': '2022-05-01T09:00:26Z',
#   'views': '193302',
#   'likes': '4579',
#   'favorites': '0'},
#  {'Title': 'Bazen uzundan kısaya 😳💈',
#   'puplished_date': '2022-04-30T15:22:07Z',
#   'views': '256279',
#   'likes': '18577',
#   'favorites': '0'},
#  {'Title': 'Bazen karıştırırsın 😳💈',
#   'puplished_date': '2022-04-28T18:17:25Z',
#   'views': '10165087',
#   'likes': '449430',
#   'favorites': '0'},
#  {'Title': "İNGİLİZ GEZGİNİN BERBER MOLASI (BUNA İHTİYACI VARDI) | BRITISH TRAVELER'S BARBER BREAK (NEEDED THIS)",
#   'puplished_date': '2022-04-27T15:21:23Z',
#   'views': '73612',
#   'likes': '1115',
#   'favorites': '0'},
#  {'Title': 'SAÇ RENGİNE KENDİ BİLE ŞAŞIRDI ! | EVEN HE WAS SURPRISED BY THE COLOR OF HAIR !',
#   'puplished_date': '2022-04-24T09:00:24Z',
#   'views': '45079',
#   'likes': '710',
#   'favorites': '0'},
#  {'Title': 'ZENGİN İŞ ADAMININ MUHTEŞEM DEĞİŞİMİ | THE MAGNIFICENT CHANGE OF A BUSINESSMAN',
#   'puplished_date': '2022-04-20T15:00:27Z',
#   'views': '94759',
#   'likes': '1301',
#   'favorites': '0'},
#  {'Title': 'Bazen boyanın doğal durmasını istersin😳💈',
#   'puplished_date': '2022-04-18T16:26:25Z',
#   'views': '169538',
#   'likes': '5803',
#   'favorites': '0'},
#  {'Title': 'JİLET GİBİ SAÇLARINI TARAK GİREMEZ HALE GETİRDİK | HOW TO MAKE A PERM ?',
#   'puplished_date': '2022-04-17T09:30:04Z',
#   'views': '73608',
#   'likes': '1032',
#   'favorites': '0'},
#  {'Title': 'Bazen değişiklik istersin 😳💈',
#   'puplished_date': '2022-04-14T15:46:28Z',
#   'views': '23376850',
#   'likes': '1585267',
#   'favorites': '0'},
#  {'Title': '💈ASMR BARBER💈 | 30 YILLIK MAKASLA TRAŞ | WE SHAVED HIM 30 YEARS OLD SCISSORS',
#   'puplished_date': '2022-04-13T15:45:01Z',
#   'views': '57234',
#   'likes': '868',
#   'favorites': '0'},
#  {'Title': 'Bazen bağlarsın 😳💈',
#   'puplished_date': '2022-04-12T17:32:34Z',
#   'views': '212192',
#   'likes': '11227',
#   'favorites': '0'},
#  {'Title': '💈ASMR 💈EVSİZ ADAMIN MANKENLERİ ARATMAYAN DÖNÜŞÜMÜ |  HOMELESS MAN BECAME A MODEL AFTER THE SHAVE',
#   'puplished_date': '2022-04-10T09:00:11Z',
#   'views': '77010',
#   'likes': '1463',
#   'favorites': '0'},
#  {'Title': 'Bazen tek Tıraşta 3 Farklı Model çıkartırsın 😳💈',
#   'puplished_date': '2022-04-07T15:19:25Z',
#   'views': '227840',
#   'likes': '10173',
#   'favorites': '0'},
#  {'Title': 'KIRMIZI TARAĞIN MUCİZESİ ! | THE MIRACLE OF THE RED COMB !',
#   'puplished_date': '2022-04-06T16:00:11Z',
#   'views': '43446',
#   'likes': '889',
#   'favorites': '0'},
#  {'Title': 'Bazen tıraşı gösteren fönüdür 😳💈',
#   'puplished_date': '2022-04-04T22:31:48Z',
#   'views': '153414',
#   'likes': '6617',
#   'favorites': '0'},
#  {'Title': 'DÜNYADAKİ EN KIVIRCIK SAÇI DÜMDÜZ YAPTIK ! | THE BIGGEST CURLY HAIR ON THE WORLD !',
#   'puplished_date': '2022-04-03T09:00:17Z',
#   'views': '169270',
#   'likes': '2178',
#   'favorites': '0'},
#  {'Title': 'Bazen ritime ayak uydurursun 😳💈',
#   'puplished_date': '2022-03-31T13:15:01Z',
#   'views': '183778',
#   'likes': '5814',
#   'favorites': '0'},
#  {'Title': 'BAZEN ESKİ SAÇLARINI YENİLERSİN | WE RENEWED HIS HAIRS',
#   'puplished_date': '2022-03-30T15:00:12Z',
#   'views': '34697',
#   'likes': '839',
#   'favorites': '0'},
#  {'Title': 'Bazen gerilirsin...😳💈',
#   'puplished_date': '2022-03-29T17:14:32Z',
#   'views': '2071000',
#   'likes': '26204',
#   'favorites': '0'},
#  {'Title': 'Bazen güncellersin 😳💈',
#   'puplished_date': '2022-03-27T19:43:18Z',
#   'views': '1629264',
#   'likes': '95432',
#   'favorites': '0'},
#  {'Title': 'KAĞIT TOPLAYAN ÇOCUKLARIN İNANILMAZ DEĞİŞİMİ ! (ÇOK EĞLENDİLER) | AMAZING CHANGE OF REFUGEE KIDS !',
#   'puplished_date': '2022-03-25T15:00:00Z',
#   'views': '222866',
#   'likes': '6194',
#   'favorites': '0'},
#  {'Title': 'ASMR BARBER | ÇIĞIRINDAN ÇIKMIŞ SAÇLARI KONTROL ALTINA ALDIK! | WE TAKE UNDER CONTROL HIS MESSY HAIR',
#   'puplished_date': '2022-03-23T15:00:01Z',
#   'views': '135194',
#   'likes': '2015',
#   'favorites': '0'},
#  {'Title': 'Bazen platin’e düşersin 😳💈',
#   'puplished_date': '2022-03-21T10:49:51Z',
#   'views': '5728350',
#   'likes': '303249',
#   'favorites': '0'},
#  {'Title': 'ASMR BARBER💈 | ÇEKİRDEK AİLE BABASIYDI, MAFYA BABASI OLDU | HE WAS A FAMILY MAN, BECOME A GODFATHER',
#   'puplished_date': '2022-03-20T09:00:18Z',
#   'views': '2563009',
#   'likes': '27179',
#   'favorites': '0'},
#  {'Title': 'Bazen ne olduğunu anlamazsın 😳💈',
#   'puplished_date': '2022-03-17T12:30:30Z',
#   'views': '1178932',
#   'likes': '22609',
#   'favorites': '0'},
#  {'Title': "BERBER KENDİNDEN UZUN SAKAL GÖRÜNCE DAYANAMADI ! | BARBER CAN'T RESIST THE LONG BEARD FROM HIS OWN !",
#   'puplished_date': '2022-03-16T15:02:45Z',
#   'views': '47468',
#   'likes': '808',
#   'favorites': '0'},
#  {'Title': 'PASLI KOYUN KIRKMA MAKASIYLA SAÇ KESTİK!! & WE SHAVED HAIR WITH RUSTY SHEARS FROM 1987 / ASMR💈',
#   'puplished_date': '2022-03-13T09:00:05Z',
#   'views': '101206',
#   'likes': '1810',
#   'favorites': '0'},
#  {'Title': 'Bazen Podolski gözüyle bakarsın 💈😁 @poldi_official',
#   'puplished_date': '2022-03-11T19:04:07Z',
#   'views': '354238',
#   'likes': '8760',
#   'favorites': '0'},
#  {'Title': 'ASMR BARBER | SAÇLARIYLA İLGİLİ HİÇBİR FİKRİ YOKTU (SONUCUNA İNANAMADI) ! | HE SHOCKED THE RESULT !',
#   'puplished_date': '2022-03-09T15:08:04Z',
#   'views': '285496',
#   'likes': '4136',
#   'favorites': '0'},
#  {'Title': '💈 FIRÇA BIYIKLIYDI, KAYTAN BIYIKLI OLDU | HE HAD BRUSH MOUSTACHE, TURNS OUT IMPERIAL MOUSTACHE 💈',
#   'puplished_date': '2022-03-06T09:00:01Z',
#   'views': '39809',
#   'likes': '771',
#   'favorites': '0'},
#  {'Title': 'Bazen nostaljik kestirirsin 😳💈',
#   'puplished_date': '2022-03-04T15:44:57Z',
#   'views': '543435',
#   'likes': '26367',
#   'favorites': '0'},
#  {'Title': "ASMR BARBER | SAKALI'NIN ALTINDAN MADEN ÇIKTI ! (İNANILMAZ DEĞİŞİM) | OLD MAN'S INCREDIBLE CHANGE !",
#   'puplished_date': '2022-03-03T15:00:16Z',
#   'views': '2536774',
#   'likes': '7363',
#   'favorites': '0'},
#  {'Title': 'Bazen çizdirirsin! 😳💈',
#   'puplished_date': '2022-03-03T06:44:21Z',
#   'views': '191584',
#   'likes': '4904',
#   'favorites': '0'},
#  {'Title': 'Bazen yanlardan al üstler kalsın..!😳💈',
#   'puplished_date': '2022-02-28T15:50:19Z',
#   'views': '18466865',
#   'likes': '835096',
#   'favorites': '0'},
#  {'Title': 'Bazen şekil verirsin 😳💈',
#   'puplished_date': '2022-02-26T08:47:37Z',
#   'views': '1983879',
#   'likes': '33156',
#   'favorites': '0'},
#  {'Title': 'ASMR | BAKIMSIZ SAÇ SAKAL TEMİZİLİĞİ (YEŞİLÇAM ARTİSTİ GİBİ OLDU) HE BECAME A MOVIE STAR',
#   'puplished_date': '2022-02-25T15:03:00Z',
#   'views': '317642',
#   'likes': '4685',
#   'favorites': '0'},
#  {'Title': 'İşitme Engelli Kardeşimize Yoğun Bakım (Yüzünden Çıkanlara İnanamayacaksınız) SKIN CARE FOR DEAF KID',
#   'puplished_date': '2022-02-22T15:00:11Z',
#   'views': '550921',
#   'likes': '6981',
#   'favorites': '0'},
#  {'Title': 'Bazen Fön Çekme Derdin Kalmaz 😉💈',
#   'puplished_date': '2022-02-19T14:25:38Z',
#   'views': '37911109',
#   'likes': '1857634',
#   'favorites': '0'},
#  {'Title': 'ASMR BARBER | DARMADAĞINDI TERTEMİZ OLDU / HE HAD MESSY HAIR BEFORE THE SHAVE',
#   'puplished_date': '2022-02-18T15:00:15Z',
#   'views': '83160',
#   'likes': '1258',
#   'favorites': '0'},
#  {'Title': 'Bazen saçların kıvrılır!!?',
#   'puplished_date': '2022-02-12T21:20:31Z',
#   'views': '48035848',
#   'likes': '2463588',
#   'favorites': '0'},
#  {'Title': "CHANGE of SUICIDAL MAN'S COFFEE SHOP and HIMSELF!  -  İNTİHARIN EŞİĞİNDEKİ ADAMIN DÖNÜŞÜMÜ!",
#   'puplished_date': '2022-02-09T20:00:17Z',
#   'views': '28489',
#   'likes': '978',
#   'favorites': '0'},
#  {'Title': 'Bazen eğlenceli kesersin!!',
#   'puplished_date': '2022-02-05T15:16:34Z',
#   'views': '134843',
#   'likes': '6999',
#   'favorites': '0'},
#  {'Title': 'ÇÖP KENARINDA EKMEK YİYEN ADAMIN DÖNÜŞÜMÜ & TRANSFORMATION OF THE MAN EATING BREAD BY THE WASTE SIDE',
#   'puplished_date': '2022-01-26T14:00:33Z',
#   'views': '1559732',
#   'likes': '27489',
#   'favorites': '0'},
#  {'Title': 'BU ÇOCUK ÇILDIRMIŞ!! KENDİ SAÇI ÜZERİNDE HERŞEYİ DENEDİ? & HE TRIED EVERYTHING ON HIS HAIR',
#   'puplished_date': '2022-01-15T18:03:36Z',
#   'views': '41664',
#   'likes': '860',
#   'favorites': '0'},
#  {'Title': 'SEYREK SAÇLI DAYIMIZA SİHİRLİ BİR DOKUNUŞ / RESMEN 20 YAŞ FARKETTİ & HAIR HAS INCREASED',
#   'puplished_date': '2021-12-31T09:00:00Z',
#   'views': '52452',
#   'likes': '1045',
#   'favorites': '0'},
#  {'Title': 'SOKAKLARIN BABASINI NOEL BABA YAPTIK!!? /Çocuklar Çok Şaşırdı! & WE MADE THE STREET MAN SANTA FATHER',
#   'puplished_date': '2021-12-29T09:00:14Z',
#   'views': '241078',
#   'likes': '4215',
#   'favorites': '0'},
#  {'Title': 'HAYATINI ÇUVALA SIĞDIRAN ADAMIN BÜYÜK DEĞİŞİMİ!!? (SAÇLAR RESMEN KÜF TUTMUŞ) & LIFE IN THE BAG',
#   'puplished_date': '2021-12-20T09:00:13Z',
#   'views': '6730100',
#   'likes': '84209',
#   'favorites': '0'},
#  {'Title': 'SOKAK ÇOCUĞU GİBİ GELDİ FUTBOLCU GİBİ GİTTİ!! & CAME LIKE A STREET CHILD, LEFT LIKE A FOOTBALLER',
#   'puplished_date': '2021-12-09T20:30:00Z',
#   'views': '439388',
#   'likes': '6378',
#   'favorites': '0'},
#  {'Title': 'SERT BAŞLAYAN TIRAŞ MUTLU SONLA BİTTİ!! & SHAVE THAT STARTS HARD WITH A HAPPY END',
#   'puplished_date': '2021-11-27T15:26:22Z',
#   'views': '44852',
#   'likes': '861',
#   'favorites': '0'},
#  {'Title': 'KATERİNA SAÇLARIMA MAKAS ATTI!! & KATERINA CUT MY HAIRS',
#   'puplished_date': '2021-11-19T16:20:01Z',
#   'views': '183529',
#   'likes': '2487',
#   'favorites': '0'},
#  {'Title': 'EVSİZ ADAM TIRAŞTAN SONRA İTALYAN MANKENİ GİBİ OLDU!! & HOMELESS MAN WAS LIKE ITALIANS AFTER SHAVING',
#   'puplished_date': '2021-11-12T17:45:22Z',
#   'views': '14112335',
#   'likes': '205675',
#   'favorites': '0'},
#  {'Title': 'BELARUSTAN GELEN KADIN ÖĞRENCİMİZE EĞİTİM VERDİK & WE PROVIDED TRAINING TO OUR STUDENT FROM BELARUS',
#   'puplished_date': '2021-11-09T14:21:54Z',
#   'views': '40492',
#   'likes': '720',
#   'favorites': '0'},
#  {'Title': 'SOKAK ADAMININ SAÇINDAN ÇIKAN KİR?? & THE MAN LIVING ON THE STREET CLEANED HAIR (ASMR)',
#   'puplished_date': '2021-10-29T22:48:56Z',
#   'views': '56349',
#   'likes': '694',
#   'favorites': '0'},
#  {'Title': 'SAÇLARINDAN ÇOK SIKILMIŞ BİR HALDEYDİ!? (Manken Gibi Oldu) & HE WAS EXTREMELY BORED WITH HAIR!',
#   'puplished_date': '2021-10-27T15:00:22Z',
#   'views': '192222',
#   'likes': '2955',
#   'favorites': '0'},
#  {'Title': 'YAŞLI AMCA DÜNYACA ÜNLÜ FUARDA MUHTEŞEM DEĞİŞİMİYLE SEYİRCİLERİ ŞOK ETTİ!!',
#   'puplished_date': '2021-10-16T13:36:08Z',
#   'views': '58052',
#   'likes': '1061',
#   'favorites': '0'},
#  {'Title': 'KILDAN YÜZÜ GÖZÜ GÖRÜNMÜYODU!!? (BURUN DELİKLERİNE DOLARLA AĞDA YAPTIK..)',
#   'puplished_date': '2021-09-22T17:30:19Z',
#   'views': '535553',
#   'likes': '5010',
#   'favorites': '0'},
#  {'Title': 'SAÇI SAKALI KONTROLDEN ÇIKMIŞ BİR MİSAFİRE ACİL MÜDAHALEDE BULUNDUK!!?',
#   'puplished_date': '2021-09-06T16:00:11Z',
#   'views': '1329263',
#   'likes': '14238',
#   'favorites': '0'},
#  {'Title': "THE TRANSFORMATION OF THE MAN WE TAKING FROM THE STREET INTO AN NBA PLAYER!! & SOKAKTAN NBA'YE ?",
#   'puplished_date': '2021-08-29T10:00:19Z',
#   'views': '63745',
#   'likes': '1305',
#   'favorites': '0'},
#  {'Title': 'SOKAKTAKİ HAYATLARIN DÖNÜŞÜMÜ!!? 2 (TIRAŞ SAHNESİ)',
#   'puplished_date': '2021-08-24T16:00:16Z',
#   'views': '56465',
# ...
#   'views': '233431',
#   'likes': '1666',
#   'favorites': '0'},
#  {'Title': 'Babamın 1 Yıllık Saçını Sakalını Kestik!!?',
#   'puplished_date': '2019-07-22T15:04:57Z',
#   'views': '3338586',
#   'likes': '26086',
#   'favorites': '0'},
#  {'Title': 'Bir Günde 3420TL Nasıl Kazandık!?',
#   'puplished_date': '2019-07-18T11:52:50Z',
#   'views': '13635',
#   'likes': '246',
#   'favorites': '0'},
#  {'Title': 'ASMR KULAK TEMİZLEME EAR CLEANİNG',
#   'puplished_date': '2019-05-29T11:47:26Z',
#   'views': '179685',
#   'likes': '5310',
#   'favorites': '0'},
#  {'Title': 'Havuz Başında 10 Bin Dolarlık Tıraş !!',
#   'puplished_date': '2019-05-21T14:06:27Z',
#   'views': '12631',
#   'likes': '162',
#   'favorites': '0'},
#  {'Title': 'ASMR ATEŞLE OYNUYOR !!',
#   'puplished_date': '2019-05-19T07:56:24Z',
#   'views': '110540',
#   'likes': '3176',
#   'favorites': '0'},
#  {'Title': 'Saçlar çok iyi oldu !!',
#   'puplished_date': '2019-04-19T11:44:56Z',
#   'views': '102872',
#   'likes': '3516',
#   'favorites': '0'},
#  {'Title': 'ASMR HEAD MASSAGE BARBER',
#   'puplished_date': '2019-04-12T12:19:16Z',
#   'views': '11414',
#   'likes': '119',
#   'favorites': '0'},
#  {'Title': 'SÖZ VERDİK TUTTUK !!',
#   'puplished_date': '2019-04-02T14:05:42Z',
#   'views': '1543360',
#   'likes': '44577',
#   'favorites': '0'},
#  {'Title': 'MÜKEMMEL SONUÇ !!?',
#   'puplished_date': '2019-03-15T20:42:46Z',
#   'views': '100752',
#   'likes': '3483',
#   'favorites': '0'},
#  {'Title': 'ADAMIN BURNUNDAN ÇIKANLARA BAKIN !!?',
#   'puplished_date': '2019-03-06T07:47:02Z',
#   'views': '99503',
#   'likes': '2480',
#   'favorites': '0'},
#  {'Title': 'YAŞLI AMCANIN MÜKEMMEL DEĞİŞİMİ',
#   'puplished_date': '2019-02-28T12:01:38Z',
#   'views': '8483',
#   'likes': '97',
#   'favorites': '0'},
#  {'Title': 'ESKİ MAKİNE İLE MÜKEMMEL BİR ÇALIŞMA',
#   'puplished_date': '2019-02-23T06:36:31Z',
#   'views': '119128',
#   'likes': '2547',
#   'favorites': '0'},
#  {'Title': 'DÜNYANIN EN ÇOK BİLİNEN BERBERİ BARBERSTOWN FOX TV',
#   'puplished_date': '2019-02-22T18:49:59Z',
#   'views': '8257',
#   'likes': '132',
#   'favorites': '0'},
#  {'Title': 'USTA KIZ ÇIRAĞINA NELER YAPTI !!',
#   'puplished_date': '2018-11-05T16:00:02Z',
#   'views': '20949',
#   'likes': '188',
#   'favorites': '0'},
#  {'Title': 'Rulo ile Saç Boyadık!!?',
#   'puplished_date': '2018-10-25T16:41:32Z',
#   'views': '80978',
#   'likes': '2306',
#   'favorites': '0'},
#  {'Title': 'Enes Batur Alev Aldı!?',
#   'puplished_date': '2018-09-09T10:58:12Z',
#   'views': '26115',
#   'likes': '231',
#   'favorites': '0'},
#  {'Title': 'ADAMA NELER OLDU NELER',
#   'puplished_date': '2018-08-28T11:59:43Z',
#   'views': '88300',
#   'likes': '2265',
#   'favorites': '0'},
#  {'Title': 'KÖFTECİ DEDE NELER İSTEDİ',
#   'puplished_date': '2018-08-14T13:28:08Z',
#   'views': '101028',
#   'likes': '3063',
#   'favorites': '0'},
#  {'Title': 'BARBER TATTO DÖVMELİ ADAM TIRAŞ OLUYOR',
#   'puplished_date': '2018-08-11T11:14:07Z',
#   'views': '17467',
#   'likes': '101',
#   'favorites': '0'},
#  {'Title': 'KİMLER GRİ BOYA İSTİYOR!??',
#   'puplished_date': '2018-07-22T19:26:26Z',
#   'views': '14455',
#   'likes': '138',
#   'favorites': '0'},
#  {'Title': 'SAÇI YANAN BAYANI KURTARDIK!!',
#   'puplished_date': '2018-07-14T10:01:17Z',
#   'views': '104643',
#   'likes': '795',
#   'favorites': '0'},
#  {'Title': 'Ünlü Model Kesim!?',
#   'puplished_date': '2018-07-09T12:07:47Z',
#   'views': '30345',
#   'likes': '325',
#   'favorites': '0'},
#  {'Title': 'Bebe Bir Traşla Kaç Yaş Büyüdü!!?',
#   'puplished_date': '2018-07-07T10:33:36Z',
#   'views': '47026',
#   'likes': '632',
#   'favorites': '0'},
#  {'Title': 'En Rahat Kullanılan Saç!!?',
#   'puplished_date': '2018-06-25T17:08:57Z',
#   'views': '32014',
#   'likes': '289',
#   'favorites': '0'},
#  {'Title': 'Türkiyeyi Trolliyen Çocuğun Çılgın Değişimi!!?',
#   'puplished_date': '2018-06-11T16:23:20Z',
#   'views': '93275',
#   'likes': '2934',
#   'favorites': '0'},
#  {'Title': 'Ramazan Davulcusu Kızını Verirmiş!?',
#   'puplished_date': '2018-06-05T16:10:29Z',
#   'views': '26091',
#   'likes': '232',
#   'favorites': '0'},
#  {'Title': 'Pazarcı Mariano Di Vaio Oldu!!',
#   'puplished_date': '2018-05-30T15:17:31Z',
#   'views': '50314',
#   'likes': '392',
#   'favorites': '0'},
#  {'Title': 'Herşey Para Değil!?',
#   'puplished_date': '2018-05-29T15:08:02Z',
#   'views': '23486',
#   'likes': '335',
#   'favorites': '0'},
#  {'Title': 'Yeni! (Gri Wax) Denedim?!',
#   'puplished_date': '2018-05-28T09:04:06Z',
#   'views': '40910',
#   'likes': '316',
#   'favorites': '0'},
#  {'Title': 'Ragnar Lothbrok Hair Style!!?',
#   'puplished_date': '2018-05-24T14:26:24Z',
#   'views': '1579778',
#   'likes': '20193',
#   'favorites': '0'},
#  {'Title': 'AĞDA ADAMI DOMATES GİBİ KIZARTTI!!',
#   'puplished_date': '2018-05-16T17:03:19Z',
#   'views': '137179',
#   'likes': '869',
#   'favorites': '0'},
#  {'Title': 'Tek Kurşun Tik Tak',
#   'puplished_date': '2018-05-05T16:23:21Z',
#   'views': '81872',
#   'likes': '1585',
#   'favorites': '0'},
#  {'Title': 'Her Erkeğin Aradığı Boya',
#   'puplished_date': '2018-04-28T16:14:17Z',
#   'views': '29132361',
#   'likes': '1315880',
#   'favorites': '0'},
#  {'Title': 'Adam Yıllar Sonra Yüz Nakli Oldu!?',
#   'puplished_date': '2018-04-14T15:26:58Z',
#   'views': '160363',
#   'likes': '545',
#   'favorites': '0'},
#  {'Title': 'En Doğru Karar?',
#   'puplished_date': '2018-04-09T15:45:56Z',
#   'views': '139338',
#   'likes': '607',
#   'favorites': '0'},
#  {'Title': 'BERBERE GİDERKEN ÖLÜYORDU!!',
#   'puplished_date': '2018-04-08T16:56:51Z',
#   'views': '21225',
#   'likes': '285',
#   'favorites': '0'},
#  {'Title': 'Ya Ben Size Gurban Olurum!',
#   'puplished_date': '2018-03-31T09:27:44Z',
#   'views': '12296',
#   'likes': '173',
#   'favorites': '0'},
#  {'Title': 'DÜN KÜNEFECİYDİ BUGÜN MANKEN OLDU!!',
#   'puplished_date': '2018-03-22T15:48:18Z',
#   'views': '468960',
#   'likes': '4034',
#   'favorites': '0'},
#  {'Title': 'ERKEK BERBERİNE KADIN GELİRSE NE OLUR?',
#   'puplished_date': '2018-03-20T15:42:04Z',
#   'views': '36212',
#   'likes': '236',
#   'favorites': '0'},
#  {'Title': 'Çiftliği Ben Soydum !',
#   'puplished_date': '2018-03-17T15:07:42Z',
#   'views': '68965',
#   'likes': '1674',
#   'favorites': '0'},
#  {'Title': 'HEP AYNI MODELLERDEN SIKILDIK !!',
#   'puplished_date': '2018-03-16T13:45:44Z',
#   'views': '67569',
#   'likes': '486',
#   'favorites': '0'},
#  {'Title': 'Kaşları Boyadı Neler Oldu',
#   'puplished_date': '2018-03-11T16:38:22Z',
#   'views': '287499',
#   'likes': '3950',
#   'favorites': '0'},
#  {'Title': 'Uzun Saçlardan Sıkıldım! Diyorsanız Kendinizi Güvenilir Ellere Bırakın',
#   'puplished_date': '2018-03-07T11:59:32Z',
#   'views': '37091',
#   'likes': '200',
#   'favorites': '0'},
#  {'Title': 'Ronaldo Saç Modeli & Ronaldo Hair Model',
#   'puplished_date': '2018-03-06T19:05:17Z',
#   'views': '24597',
#   'likes': '129',
#   'favorites': '0'},
#  {'Title': 'Çorumlu Amir Berberde Neler Yaşadı',
#   'puplished_date': '2018-02-28T13:48:01Z',
#   'views': '930045',
#   'likes': '5485',
#   'favorites': '0'},
#  {'Title': 'Mihriban (Çukur)',
#   'puplished_date': '2018-02-20T14:51:21Z',
#   'views': '7434',
#   'likes': '83',
#   'favorites': '0'},
#  {'Title': 'Kendi Saçlarımı Boyadım!! (Eğitici)',
#   'puplished_date': '2018-02-18T14:35:19Z',
#   'views': '12839',
#   'likes': '117',
#   'favorites': '0'},
#  {'Title': 'Alex Telles Saç Modeli & Alex Telles Hair Model',
#   'puplished_date': '2018-02-16T17:21:39Z',
#   'views': '57848',
#   'likes': '1272',
#   'favorites': '0'},
#  {'Title': 'Sokaktaki Vatandaşları Kışkırttık Saçları Kestirdik !!!',
#   'puplished_date': '2018-02-06T19:04:47Z',
#   'views': '9284',
#   'likes': '172',
#   'favorites': '0'},
#  {'Title': 'Berberin makasını yere düşürünce Müşteri’nin başına neler geldi izleyin ve görün',
#   'puplished_date': '2018-02-02T15:40:03Z',
#   'views': '22030',
#   'likes': '180',
#   'favorites': '0'},
#  {'Title': 'İki Usta Elin Birleşmesi Saç Renklendirme Kesim Dünya Sıralamasına Girer',
#   'puplished_date': '2018-01-31T17:46:49Z',
#   'views': '32214',
#   'likes': '184',
#   'favorites': '0'},
#  {'Title': 'Acı Çekmek Yaşam Tarzı',
#   'puplished_date': '2018-01-28T10:08:14Z',
#   'views': '266249',
#   'likes': '1930',
#   'favorites': '0'},
#  {'Title': 'Böyle Kavga Görülmedi',
#   'puplished_date': '2018-01-26T15:51:22Z',
#   'views': '53407',
#   'likes': '1335',
#   'favorites': '0'},
#  {'Title': '10 Yaşında Sakalları Jiletle Kestiriyor',
#   'puplished_date': '2018-01-26T09:33:46Z',
#   'views': '139260',
#   'likes': '2056',
#   'favorites': '0'},
#  {'Title': 'Kendi Kendini Vurdu',
#   'puplished_date': '2018-01-25T13:48:47Z',
#   'views': '79769',
#   'likes': '1263',
#   'favorites': '0'},
#  {'Title': 'Before & After',
#   'puplished_date': '2018-01-16T14:29:06Z',
#   'views': '3888590',
#   'likes': '12960',
#   'favorites': '0'},
#  {'Title': 'En Kullanışlı Saç Modeli',
#   'puplished_date': '2018-01-14T17:17:17Z',
#   'views': '16248',
#   'likes': '116',
#   'favorites': '0'},
#  {'Title': 'Yanıyorsun Fuat Abi (brazilya fönü)',
#   'puplished_date': '2018-01-13T15:40:02Z',
#   'views': '58531',
#   'likes': '878',
#   'favorites': '0'},
#  {'Title': '4 Yıllık Uzattığı Saçlar Gitti',
#   'puplished_date': '2018-01-12T15:22:55Z',
#   'views': '166438',
#   'likes': '545',
#   'favorites': '0'},
#  {'Title': 'Koca Bebek Hüngür Hüngür Ağladı',
#   'puplished_date': '2018-01-09T15:29:12Z',
#   'views': '43487',
#   'likes': '309',
#   'favorites': '0'},
#  {'Title': 'Korktun Mu?',
#   'puplished_date': '2018-01-06T16:00:15Z',
#   'views': '97355',
#   'likes': '1695',
#   'favorites': '0'},
#  {'Title': 'Haylaz Bebe',
#   'puplished_date': '2018-01-02T17:20:52Z',
#   'views': '24311',
#   'likes': '272',
#   'favorites': '0'},
#  {'Title': '40 Yıldır Mağarada Yaşayan Adam',
#   'puplished_date': '2018-01-01T16:40:54Z',
#   'views': '3131800',
#   'likes': '6738',
#   'favorites': '0'},
#  {'Title': 'Marul Ve Babası’nın En Komik Anları Barberstown’da',
#   'puplished_date': '2017-12-31T10:14:48Z',
#   'views': '92363',
#   'likes': '547',
#   'favorites': '0'},
#  {'Title': 'Sıfır Bir',
#   'puplished_date': '2017-12-28T15:47:17Z',
#   'views': '32693',
#   'likes': '157',
#   'favorites': '0'},
#  {'Title': 'Atsan Atılmaz Satsan Satılmaz',
#   'puplished_date': '2017-12-27T17:39:52Z',
#   'views': '44989',
#   'likes': '805',
#   'favorites': '0'},
#  {'Title': 'Sizin Açık Gözle Yapamadığınızı Adam Gözü Kapalı Yapıyor',
#   'puplished_date': '2017-12-25T18:04:32Z',
#   'views': '36639',
#   'likes': '231',
#   'favorites': '0'},
#  {'Title': 'Eskiyi Getir Yeniyi Götür',
#   'puplished_date': '2017-12-23T14:52:25Z',
#   'views': '488778',
#   'likes': '1819',
#   'favorites': '0'},
#  {'Title': 'Çağatay Ulusoy Saç Modeli (içerde dizisi)',
#   'puplished_date': '2017-12-22T15:01:20Z',
#   'views': '222994',
#   'likes': '2652',
#   'favorites': '0'},
#  {'Title': 'Dev Ustura İle Sakal Kestik Olay Oldu',
#   'puplished_date': '2017-12-21T13:31:44Z',
#   'views': '54296',
#   'likes': '794',
#   'favorites': '0'},
#  {'Title': 'Bu Bir Mucize Değil Yetenek',
#   'puplished_date': '2017-12-20T16:29:25Z',
#   'views': '835620',
#   'likes': '2260',
#   'favorites': '0'},
#  {'Title': 'Kardeş Bizi İnternete Falan Koymucanız Demi La',
#   'puplished_date': '2017-12-20T10:50:30Z',
#   'views': '87093',
#   'likes': '814',
#   'favorites': '0'},
#  {'Title': 'Yattı Yatırdı Düştü Kalktı Kesti',
#   'puplished_date': '2017-12-19T15:34:52Z',
#   'views': '17820',
#   'likes': '152',
#   'favorites': '0'},
#  {'Title': 'Saçlara Beyaz Show',
#   'puplished_date': '2017-12-16T15:11:15Z',
#   'views': '58145',
#   'likes': '263',
#   'favorites': '0'},
#  {'Title': 'Adamın Saçı Yaktık Olay Oldu',
#   'puplished_date': '2017-12-12T15:12:11Z',
#   'views': '220634',
#   'likes': '664',
#   'favorites': '0'},
#  {'Title': 'Gelmiş geçmiş en ilginç en kaliteli kuaför & The most interesting top quality barber ever',
#   'puplished_date': '2017-12-10T14:21:01Z',
#   'views': '116921',
#   'likes': '479',
#   'favorites': '0'},
#  {'Title': 'Neydi ne oldu ?',
#   'puplished_date': '2017-12-06T17:47:37Z',
#   'views': '128556',
#   'likes': '3246',
#   'favorites': '0'},
#  {'Title': 'Meriç İzgi erkek çocuğunu ilk defa Barberstowna traşa getirdi',
#   'puplished_date': '2017-12-02T15:44:21Z',
#   'views': '47727',
#   'likes': '224',
#   'favorites': '0'},
#  {'Title': 'Yanları al üstler kalsın',
#   'puplished_date': '2017-12-01T15:58:54Z',
#   'views': '272795',
#   'likes': '5333',
#   'favorites': '0'},
#  {'Title': 'Son 100 yılın değişimi &  The last 100 years of change',
#   'puplished_date': '2017-11-29T15:48:54Z',
#   'views': '217144',
#   'likes': '754',
#   'favorites': '0'},
#  {'Title': '0 dan iz kaybetme & Lose track from 0',
#   'puplished_date': '2017-11-28T15:18:01Z',
#   'views': '109532',
#   'likes': '1250',
#   'favorites': '0'},
#  {'Title': 'Omre hair men uzun saçlı erkek saçına yoğun krepe ve omre düz fon',
#   'puplished_date': '2017-11-26T11:59:18Z',
#   'views': '39935',
#   'likes': '174',
#   'favorites': '0'},
#  {'Title': 'Ağaç Motoru İle Sakal Kesti & Cutting beard with saw',
#   'puplished_date': '2017-11-18T09:23:06Z',
#   'views': '29737',
#   'likes': '541',
#   'favorites': '0'},
#  {'Title': 'Göz Akımı Başladı Ve Barberstown Bunu Saç Kesimi İle Birleştirdi !!',
#   'puplished_date': '2017-11-15T12:01:09Z',
#   'views': '61510',
#   'likes': '240',
#   'favorites': '0'},
#  {'Title': 'Adam Bir Anda Saçını Usturaya Vurdurdu',
#   'puplished_date': '2017-11-13T09:42:19Z',
#   'views': '525805',
#   'likes': '1166',
#   'favorites': '0'},
#  {'Title': 'Eminem Saç Modeli İstedi Bizde Yaptık & Eminem Hair Model Wanted',
#   'puplished_date': '2017-11-09T14:50:52Z',
#   'views': '114445',
#   'likes': '427',
#   'favorites': '0'},
#  {'Title': 'Can Yüce’nin Kuaförü Kim ?',
#   'puplished_date': '2017-11-05T14:46:13Z',
#   'views': '53971',
#   'likes': '877',
#   'favorites': '0'},
#  {'Title': 'Kaş Nasıl Alınır',
#   'puplished_date': '2017-11-04T11:17:47Z',
#   'views': '190270',
#   'likes': '459',
#   'favorites': '0'},
#  {'Title': 'Kısa Saça Nasıl Fön Çekilir & How to Draw Short Hair',
#   'puplished_date': '2017-11-02T15:45:31Z',
#   'views': '278567',
#   'likes': '1798',
#   'favorites': '0'},
#  {'Title': 'Cadılar Bayramında Korku Temalı Saç Kesimi & Horror-themed Haircut on Halloween',
#   'puplished_date': '2017-10-31T16:46:56Z',
#   'views': '4551',
#   'likes': '75',
#   'favorites': '0'},
#  {'Title': 'Pırasa Kafaydı Burak Özcivit Oldu Çıktı',
#   'puplished_date': '2017-10-31T10:41:27Z',
#   'views': '1052250',
#   'likes': '3772',
#   'favorites': '0'},
#  {'Title': 'Bu Saç Kesimi Çok Beğenildi & This haircut is very popular',
#   'puplished_date': '2017-10-30T10:06:16Z',
#   'views': '86042',
#   'likes': '461',
#   'favorites': '0'},
#  {'Title': 'Uzun Saçın Aralarına Delikli Boneyle Boya yaptık',
#   'puplished_date': '2017-10-18T17:29:54Z',
#   'views': '455256',
#   'likes': '1080',
#   'favorites': '0'},
#  {'Title': 'En İyi Kısa Saç Modeli & Best short hairstyle',
#   'puplished_date': '2017-10-17T16:47:37Z',
#   'views': '152688',
#   'likes': '457',
#   'favorites': '0'},
#  {'Title': 'ZİRVEDE SAÇ KESTİ & HIGH HAIR CUTTING',
#   'puplished_date': '2017-10-11T16:05:23Z',
#   'views': '2661',
#   'likes': '42',
#   'favorites': '0'},
#  {'Title': 'Dalgalı Ve Kıvırcık Saçlara Tarak Kullanmadan Düzleştirip Şekillendiriyor',
#   'puplished_date': '2017-09-14T16:20:18Z',
#   'views': '487721',
#   'likes': '4415',
#   'favorites': '0'},
#  {'Title': 'Marul Kafa Ne İş Yapar ?',
#   'puplished_date': '2017-09-07T15:13:16Z',
#   'views': '755366',
#   'likes': '6731',
#   'favorites': '0'},
#  {'Title': "DÜNYA'NIN EN TATLI BEBEĞİ SAÇLARINI KESTİRİYOR & BABY HAİRCUT",
#   'puplished_date': '2017-09-05T17:51:36Z',
#   'views': '638043',
#   'likes': '5828',
#   'favorites': '0'},
#  {'Title': 'İkizler Saç Kesimi & Twins haircut',
#   'puplished_date': '2017-08-26T09:03:20Z',
#   'views': '215400',
#   'likes': '830',
#   'favorites': '0'},
#  {'Title': "Meriç İzgi'nin Kuaförü Kim & Who is the hairdresser of Meriç İzgi",
#   'puplished_date': '2017-08-12T17:36:08Z',
#   'views': '654531',
#   'likes': '2000',
#   'favorites': '0'},
#  {'Title': '11 yaşındaki çocuk bakın neler yapıyo gri saç boyuyor',
#   'puplished_date': '2017-05-23T18:19:32Z',
#   'views': '169287',
#   'likes': '790',
#   'favorites': '0'},
#  {'Title': 'Saça fön nasıl çekilir',
#   'puplished_date': '2017-05-16T19:12:45Z',
#   'views': '49088',
#   'likes': '334',
#   'favorites': '0'},
#  {'Title': 'Erkek Saçına Gri boya nasıl yapılır',
#   'puplished_date': '2017-04-22T13:00:22Z',
#   'views': '40459',
#   'likes': '804',
#   'favorites': '0'}]

# %%
video_data = pd.DataFrame(video_data)
video_data
# Out:
#                                                  Title        puplished_date  \
# 0                       Bazen aralara doğal dokunuş 😳💈  2025-01-01T14:58:18Z
# 1                            Bazen ders niteliğinde 😳💈  2024-12-30T16:36:14Z
# 2                                     Bazen aralara 😳💈  2024-12-27T14:38:07Z
# 3    SICACIK SOHBET EŞLİĞİNDE EVSİZ ADAMA YEPYENİ B...  2024-12-26T08:51:44Z
# 4    Bazen saç herşeyi değiştirir 😳💈 #barberstown #...  2024-12-24T14:35:49Z
# ..                                                 ...                   ...
# 517                 İkizler Saç Kesimi & Twins haircut  2017-08-26T09:03:20Z
# 518  Meriç İzgi'nin Kuaförü Kim & Who is the hairdr...  2017-08-12T17:36:08Z
# 519  11 yaşındaki çocuk bakın neler yapıyo gri saç ...  2017-05-23T18:19:32Z
# 520                             Saça fön nasıl çekilir  2017-05-16T19:12:45Z
# 521                Erkek Saçına Gri boya nasıl yapılır  2017-04-22T13:00:22Z
#
#       views likes favorites
# 0      7838   156         0
# 1      3847   153         0
# 2      7158   148         0
# 3      5276   161         0
# 4     14913   330         0
# ..      ...   ...       ...
# 517  215400   830         0
# 518  654531  2000         0
# 519  169287   790         0
# 520   49088   334         0
# 521   40459   804         0
#
# [522 rows x 5 columns]

# %% [markdown]
# En çok izlenen 10 videoyu büyükten küçüğe doğru sıralayarak dataframe tipinde yazdırınız.

# %%
video_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522 entries, 0 to 521
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           522 non-null    object
#  1   puplished_date  522 non-null    object
#  2   views           522 non-null    object
#  3   likes           522 non-null    object
#  4   favorites       522 non-null    object
# dtypes: object(5)
# memory usage: 20.5+ KB

# %%
video_data['views'] = pd.to_numeric(video_data['views'])
video_data['likes'] = pd.to_numeric(video_data['likes'])
#video_data['comments'] = pd.to_numeric(video_data['comments'])
video_data['favorites'] = pd.to_numeric(video_data['favorites'])

# %%
video_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
top_10_videos = video_data.sort_values(by = 'views', ascending= False).head(10)
top_10_videos
# Out:
#                                                  Title        puplished_date  \
# 107                          Bazen yanlış oturursun 😳💈  2023-05-22T22:24:43Z
# 86   Bazen maksimum doğum günü süprizi 😳🥳💈 en güzel...  2023-08-21T17:39:17Z
# 19                               Bazen tekrar yaparsın  2024-11-10T08:58:41Z
# 72                        Bazen oturmayı öğrenirsin 😳💈  2023-12-01T14:37:12Z
# 270                         Bazen saçların kıvrılır!!?  2022-02-12T21:20:31Z
# 268                   Bazen Fön Çekme Derdin Kalmaz 😉💈  2022-02-19T14:25:38Z
# 451                           Her Erkeğin Aradığı Boya  2018-04-28T16:14:17Z
# 209                               Bazen tek atarsın 😳💈  2022-06-13T18:05:53Z
# 89                           Bazen yanlış bağlarsın 😳💈  2023-08-14T16:07:41Z
# 239                       Bazen değişiklik istersin 😳💈  2022-04-14T15:46:28Z
#
#          views    likes  favorites
# 107  507570337  6850736          0
# 86   117418100   879266          0
# 19    60814058   724647          0
# 72    57866500   537509          0
# 270   48035848  2463588          0
# 268   37911109  1857634          0
# 451   29132361  1315880          0
# 209   27696935   520579          0
# 89    25432478   314859          0
# 239   23376850  1585267          0

# %% [markdown]
# # Yukarda oluşturduğumuz veri setini sns.barplot() methodunu kullanarak görselleştiriniz.

# %%
ax = sns.barplot(x = top_10_videos['views'], y = top_10_videos['Title'], orient='h')
plt.xticks(rotation = 90)
plt.show()
# Out:
# /workspaces/Youtube_Web_Api_Project/sanal_ortam/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128136 (\N{BARBER POLE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /workspaces/Youtube_Web_Api_Project/sanal_ortam/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 129395 (\N{FACE WITH PARTY HORN AND PARTY HAT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /workspaces/Youtube_Web_Api_Project/sanal_ortam/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 129321 (\N{GRINNING FACE WITH STAR EYES}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /workspaces/Youtube_Web_Api_Project/sanal_ortam/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 129782 (\N{HEART HANDS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /workspaces/Youtube_Web_Api_Project/sanal_ortam/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 127995 (\N{EMOJI MODIFIER FITZPATRICK TYPE-1-2}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
video_data['puplished_date']
# Out:
# 0      2025-01-01T14:58:18Z
# 1      2024-12-30T16:36:14Z
# 2      2024-12-27T14:38:07Z
# 3      2024-12-26T08:51:44Z
# 4      2024-12-24T14:35:49Z
#                ...
# 517    2017-08-26T09:03:20Z
# 518    2017-08-12T17:36:08Z
# 519    2017-05-23T18:19:32Z
# 520    2017-05-16T19:12:45Z
# 521    2017-04-22T13:00:22Z
# Name: puplished_date, Length: 522, dtype: object

# %% [markdown]
# # Soru
#
# to_datetime() methodu ile string bir datayı zaman tipine çevirebilirsin.
# .dt.strftime() ile zaman tipi içerisinden istediğin bilgiyi çıkarabilirsin. .dt.strftime('%b') sadece ayları alırsın .dt.strftime('%y') sadece yılları alırsın

# %%
video_data['month'] =  pd.to_datetime(video_data['puplished_date']).dt.strftime('%b')
video_data['year'] = pd.to_datetime(video_data['puplished_date']).dt.strftime('%y')

# %% [markdown]
# #Alıştırmalar

# %% [markdown]
# video_data üzerinden 2023 ve 2024 verilerini indexleyerek  yeni bir veri setine atayınız.

# %%
video_data_filtered = video_data[video_data['year'].isin(['23','24'])]
video_data_filtered
# Out:
#                                                  Title        puplished_date  \
# 1                            Bazen ders niteliğinde 😳💈  2024-12-30T16:36:14Z
# 2                                     Bazen aralara 😳💈  2024-12-27T14:38:07Z
# 3    SICACIK SOHBET EŞLİĞİNDE EVSİZ ADAMA YEPYENİ B...  2024-12-26T08:51:44Z
# 4    Bazen saç herşeyi değiştirir 😳💈 #barberstown #...  2024-12-24T14:35:49Z
# 5    Bazen kaymak gibi 😳💈 #barberstown  #teambarber...  2024-12-20T15:21:10Z
# ..                                                 ...                   ...
# 128                                   Bazen special 😳💈  2023-01-30T20:23:00Z
# 129                           Bazen havalı girersin 😳💈  2023-01-26T17:17:42Z
# 130                           Bazen yanlış anlarsın 😳💈  2023-01-25T14:22:52Z
# 131                    Bazen gözlerini kaçıramazsın 😳💈  2023-01-24T15:00:16Z
# 132                        Bazen uçlarından alırsın 😳💈  2023-01-21T14:27:50Z
#
#       views  likes  favorites month year
# 1      3847    153          0   Dec   24
# 2      7158    148          0   Dec   24
# 3      5276    161          0   Dec   24
# 4     14913    330          0   Dec   24
# 5      5740    195          0   Dec   24
# ..      ...    ...        ...   ...  ...
# 128  128685   5348          0   Jan   23
# 129  165582   5870          0   Jan   23
# 130  118548   4203          0   Jan   23
# 131  153877   3166          0   Jan   23
# 132  102176   1924          0   Jan   23
#
# [132 rows x 7 columns]

# %% [markdown]
# 100000 like altı alan videoları büyükten küçüğe doğru sıralayın.

# %%
video_data_filtered = video_data
